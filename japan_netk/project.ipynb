# %%
# load train_network.gexf
import networkx as nx
G = nx.read_gexf("train_network_jp_coords_filtered.gexf")

# print the number of nodes and edges
print("Number of nodes: ", G.number_of_nodes())
print("Number of edges: ", G.number_of_edges())
# Out:
# Number of nodes:  789
# Number of edges:  743

# %%
# convert the graph to an undirected simple graph
undirected_G = G.to_undirected()

# %%
undirected_G.number_of_nodes()
undirected_G.number_of_edges()
# Out:
# 743

# %%
# generate degree distribution of undirected_G
import collections
degree_sequence = sorted([d for n, d in undirected_G.degree()], reverse=True)  # degree sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

# %%
# import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

def plot_degree_distribution(G):
    """
    Generates and plots the degree distribution of an undirected graph.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        dict: A dictionary where keys are degrees and values are their frequencies.
    """
    # Get the degree of each node
    degrees = [degree for _, degree in G.degree()]

    # Count the frequency of each degree
    degree_counts = Counter(degrees)

    # Separate degrees and their frequencies for plotting
    x, y = zip(*sorted(degree_counts.items()))

    
    total_nodes = G.number_of_nodes()

    # Normalize the frequency of each degree
    y = [count / total_nodes for count in y]
    

    # Plot the degree distribution
    plt.figure(figsize=(8, 6))
    plt.bar(x, y, width=0.8, color='b', alpha=0.7, edgecolor='k')
    plt.title('Degree Distribution', fontsize=14)
    plt.xlabel('Degree', fontsize=12)
    plt.ylabel('Probability', fontsize=12)
    plt.xticks(range(0, max(x) + 1))
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

    # plot log-log degree distribution
    plt.figure(figsize=(8, 6))
    plt.loglog(x, y, 'bo', alpha=0.7)
    plt.title('Log-Log Degree Distribution', fontsize=14)
    plt.xlabel('Degree', fontsize=12)
    plt.ylabel('Probability', fontsize=12)
    plt.grid(True, which="both", ls="--", alpha=0.7)
    plt.show()

    return dict(degree_counts)

# %%
plot_degree_distribution(undirected_G)
# Out:
# {2: 668, 3: 14, 1: 100, 0: 5, 4: 2}

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

def plot_giant_component_vs_node_removal(G, removal_strategy="random", title = "Random Failures"):
    """
    Plots the size of the giant component vs the fraction of nodes removed.

    Parameters:
        G (networkx.Graph): The input graph.
        removal_strategy (str): The strategy for node removal ('random' or 'degree').
    """
    # Make a copy of the graph
    G = G.copy()
    num_nodes = G.number_of_nodes()

    # List to store the fraction of nodes removed and size of the giant component
    fractions_removed = []
    giant_component_sizes = []

    # Generate a list of nodes to remove
    if removal_strategy == "degree":
        # Remove nodes by descending degree
        nodes = sorted(G.degree, key=lambda x: x[1], reverse=True)
        nodes = [node for node, _ in nodes]
    elif removal_strategy == "random":
        # Remove nodes in random order
        nodes = list(G.nodes)
        random.shuffle(nodes)
    else:
        raise ValueError("Invalid removal strategy. Choose 'random' or 'degree'.")

    # Remove nodes one by one and compute the size of the giant component
    for i, node in enumerate(nodes):
        G.remove_node(node)
        largest_cc = max(nx.connected_components(G), key=len, default=[])
        fractions_removed.append((i + 1) / num_nodes)  # Fraction of nodes removed
        giant_component_sizes.append(len(largest_cc) / num_nodes )  # Size of the giant component

    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(fractions_removed, giant_component_sizes, label=f"Strategy: {removal_strategy}")
    plt.title(title, fontsize=14)
    plt.xlabel("Fraction of Nodes Removed", fontsize=12)
    plt.ylabel("Size of Giant Component", fontsize=12)
    plt.grid(alpha=0.7)
    plt.legend(fontsize=10)
    plt.show()

# %%
plot_giant_component_vs_node_removal(undirected_G, "random")

# %%
plot_giant_component_vs_node_removal(undirected_G, "degree", "Attack Tolearance")

# %%
import networkx as nx
import community as community_louvain
import matplotlib.pyplot as plt

def detect_communities(G):
    """
    Detects communities in an undirected graph using the Louvain algorithm.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        dict: A dictionary where keys are nodes and values are community IDs.
    """
    # Compute the best partition (community structure)
    partition = community_louvain.best_partition(G)
    
    return partition

def plot_large_communities(G, partition):
    """
    Plots large graphs with communities in a visually clear manner.

    Parameters:
        G (networkx.Graph): The input graph.
        partition (dict): A dictionary mapping nodes to community IDs.
    """
    # Assign colors to nodes based on their community
    node_colors = [partition[node] for node in G.nodes()]

    # Use a spring layout for better spacing
    pos = nx.spring_layout(G, seed=42)  # Adjust seed for consistent layout

    plt.figure(figsize=(12, 8))
    nx.draw(
        G,
        pos,
        node_color=node_colors,
        cmap=plt.cm.tab20,
        node_size=100,  # Adjust node size
        edge_color="gray",
        alpha=0.7,  # Transparency for edges
        with_labels=False  # Hide labels for clarity
    )
    plt.title("Communities in the Network (Simplified)", fontsize=16)
    plt.show()

# %%
# Detect communities
communities = detect_communities(undirected_G)

# Print the communities (node-to-community mapping)
print("Node-to-Community Mapping:")
print(communities)

# Plot the graph with community coloring
plot_large_communities(undirected_G, communities)
# Out:
# Node-to-Community Mapping:
# {'Kogota': 0, 'Kami-Wakuya': 0, 'Wakuya': 0, 'Maeyachi': 0, 'Kakeyama': 0, 'Kanomata': 0, 'Sobanokami': 0, 'Ishinomaki': 0, 'Rikuzen-Inai': 0, 'Watanoha': 0, 'Mangokuura': 0, 'Sawada': 0, 'Urashuku': 0, 'Onagawa': 0, 'Sawara': 2, 'Katori': 2, 'Jūnikyō': 2, 'Itako': 2, 'Nobukata': 2, 'Kashimajingū': 2, 'Kashima-Soccer Stadium（Seasonal）': 2, 'Chiba': 4, 'Higashi-Chiba': 4, 'Tsuga': 4, 'Yotsukaidō': 4, 'Monoi': 4, 'Sakura': 4, 'Minami-Shisui': 4, 'Yachimata': 5, 'Narutō': 4, 'Matsuo': 4, 'Yokoshiba': 4, 'Iigura': 4, 'Yōkaichiba': 4, 'Higata': 4, 'Asahi': 4, 'Iioka': 4, 'Kurahashi': 2, 'Saruda': 2, 'Matsugishi': 2, 'Chōshi': 2, 'Chigasaki': 7, 'Kita-Chigasaki': 7, 'Samukawa': 8, 'Miyayama': 8, 'Kurami': 8, 'Kadosawabashi': 8, 'Shake': 8, 'Atsugi': 8, 'Ebina': 8, 'Iriya': 8, 'Sōbudaishita': 8, 'Shimomizo': 8, 'Harataima': 8, 'Banda': 8, 'Kamimizo': 8, 'Minami-Hashimoto': 8, 'Kitaura': 0, 'Rikuzen-Yachi': 0, 'Furukawa': 0, 'Tsukanome': 0, 'Nishi-Furukawa': 0, 'Higashi-Ōsaki': 0, 'Nishi-Ōsaki': 10, 'Iwadeyama': 10, 'Yūbikan': 10, 'Kaminome': 10, 'Ikezuki': 10, 'Kawatabi-Onsen': 10, 'Narukogotenyu': 10, 'Naruko-Onsen': 10, 'Nakayamadaira-Onsen': 10, 'Sakaida': 10, 'Akakura-Onsen': 10, 'Tachikōji': 10, 'Mogami': 10, 'Ōhori': 10, 'Usugi': 10, 'Semi-Onsen': 10, 'Higashi-Nagasawa': 10, 'Nagasawa': 10, 'Minami-Shinjō': 10, 'Shinjō': 10, 'Aomori': 11, 'Aburakawa': 11, 'Tsugaru-Miyata': 11, 'Okunai': 11, 'Hidariseki': 11, 'Ushirogata': 11, 'Nakasawa': 11, 'Yomogita': 11, 'Gōsawa': 11, 'Seheji': 11, 'Kanita': 11, 'Ōdai': 12, 'Tsugaru-Futamata': 12, 'Ōkawadai': 12, 'Imabetsu': 12, 'Tsugaru-Hamana': 12, 'Mimmaya': 12, 'Atami': 13, 'Kinomiya': 13, 'Izu-Taga': 13, 'Ajiro': 13, 'Usami': 13, 'Itō': 13, 'Hama-Kawasaki': 14, 'Odasakae': 14, 'Kawasakishimmachi': 14, 'Hatchōnawate': 14, 'Shitte': 14, 'Hon-Chiba': 4, 'Soga': 4, 'Hamano': 4, 'Yawatajuku': 4, 'Goi': 4, 'Anegasaki': 4, 'Nagaura': 4, 'Sodegaura': 4, 'Iwane': 4, 'Kisarazu': 4, 'Kimitsu': 4, 'Aohori': 4, 'Ōnuki': 4, 'Sanukimachi': 4, 'Kazusa-Minato': 4, 'Hama-Kanaya': 16, 'Hota': 16, 'Awa-Katsuyama': 16, 'Iwai': 16, 'Tomiura': 16, 'Nakofunakata': 16, 'Tateyama': 16, 'Chikura': 17, 'Minamihara': 18, 'Wadaura': 18, 'Emi': 18, 'Awa-Kamogawa': 19, 'Hanamaki': 20, 'Nitanai': 20, 'Shin-Hanamaki': 20, 'Oyamada': 20, 'Tsuchizawa': 20, 'Haruyama': 20, 'Iwanebashi': 20, 'Miyamori': 20, 'Kashiwagidaira': 20, 'Masuzawa': 20, 'Arayamae': 20, 'Iwate-Futsukamachi': 20, 'Ayaori': 20, 'Tōno': 20, 'Aozasa': 20, 'Iwate-Kamigō': 20, 'Hirakura': 20, 'Ashigase': 20, 'Kami-Arisu': 20, 'Rikuchū-Ōhashi': 20, 'Dōsen': 20, 'Matsukura': 20, 'Kosano': 20, 'Kamaishi': 20, 'Shisui': 4, 'Narita': 2, 'Narita Airport Terminal 2・3': 2, 'Narita Airport Terminal 1': 2, 'Jimbohara': 22, 'Shimmachi': 22, 'Kuragano': 22, 'Takasaki': 22, 'Kobuchizawa': 23, 'Kai-Koizumi': 23, 'Kai-Ōizumi': 23, 'Nobeyama': 24, 'Shinano-Kawakami': 24, 'Saku-Hirose': 24, 'Saku-Uminokuchi': 24, 'Umijiri': 24, 'Matsubarako': 24, 'Koumi': 24, 'Managashi': 24, 'Yachiho': 25, 'Haguroshita': 26, 'Aonuma': 26, 'Usuda': 26, 'Tatsuokajō': 26, 'Ōtabe': 26, 'Nakagomi': 26, 'Namezu': 26, 'Kita-Nakagomi': 26, 'Iwamurada': 26, 'Sakudaira': 26, 'Nakasato': 26, 'Misato': 26, 'Mitsuoka': 26, 'Otome': 26, 'Higashi-Komoro': 26, 'Komoro': 26, 'Sendai': 27, 'Tōshōgū': 27, 'Kita-Sendai': 27, 'Tōhoku Fukushi University': 28, 'Kunimi': 28, 'Kuzuoka': 28, 'Rikuzen-Ochiai': 28, 'Ayashi': 28, 'Rikuzen-Shirasawa': 28, 'Kumagane': 28, 'Sakunami': 28, 'Oku-Nikkawa': 28, 'Omoshiroyama-Kōgen': 28, 'Yamadera': 28, 'Uzen-Chitose': 16, 'Kita-Yamagata': 16, 'Yamagata': 16, 'Aizu-Wakamatsu': 29, 'Nanukamachi': 29, 'Nishi-Wakamatsu': 29, 'Aizu-Hongō': 29, 'Aizu-Takada': 29, 'Negishi': 29, 'Niitsuru': 29, 'Wakamiya': 29, 'Aizu-Bange': 29, 'Tōdera': 29, 'Aizu-Sakamoto': 29, 'Aizu-Yanaizu': 29, 'Gōdo': 29, 'Takiya': 29, 'Aizu-Hinohara': 29, 'Aizu-Nishikata': 29, 'Aizu-Miyashita': 29, 'Aizu-Mizunuma': 30, 'Aizu-Nakagawa': 30, 'Aizu-Kawaguchi': 30, 'Honna': 30, 'Aizu-Kosugawa': 30, 'Aizu-Yokota' ...

# %%
import networkx as nx
import community as community_louvain
import matplotlib.pyplot as plt
from shapely.geometry import Point
import geopandas as gpd
from shapely.geometry import LineString
import random
import numpy as np

# Set random seed
random.seed(42)
np.random.seed(42)

def plot_communities_on_map(G, partition, base_map_gdf):
    """
    Plots communities on a geographic map using node coordinates.

    Parameters:
        G (networkx.Graph): The input graph.
        partition (dict): A dictionary mapping nodes to community IDs.
        base_map_gdf (GeoDataFrame): The geographic base map.
    """
    # Extract node coordinates and community info
    base_map_gdf['color'] = base_map_gdf.index % 10
    nodes = []
    for node, data in G.nodes(data=True):
        if 'latitude' in data and 'longitude' in data:
            try:
                lat = float(data['latitude'])
                lon = float(data['longitude'])
                community_id = partition[node]
                nodes.append({'id': node, 'geometry': Point(lon, lat), 'community': community_id})
            except ValueError:
                print(f"Invalid coordinates for node {node}, skipping.")

    # Create GeoDataFrame for nodes
    stations_gdf = gpd.GeoDataFrame(nodes)

    # Plot the base map
    fig, ax = plt.subplots(figsize=(15, 15))
    base_map_gdf.plot(column='color', cmap='tab20', legend=False, ax=ax, alpha=0.3, edgecolor='black')

    # Plot nodes (train stations) colored by community
    stations_gdf.plot(
        ax=ax,
        column='community',  # Color by community
        cmap='tab20',
        markersize=50,
        # legend=True,
        legend_kwds={'label': "Community"},
        edgecolor='black',
    )

    # Plot edges
    edges = []
    for u, v in G.edges():
        u_data = G.nodes[u]
        v_data = G.nodes[v]
        if 'latitude' in u_data and 'longitude' in u_data and 'latitude' in v_data and 'longitude' in v_data:
            try:
                line = LineString([
                    Point(float(u_data['longitude']), float(u_data['latitude'])),
                    Point(float(v_data['longitude']), float(v_data['latitude']))
                ])
                edges.append({'geometry': line})
            except ValueError:
                print(f"Invalid edge coordinates between {u} and {v}, skipping.")
    routes_gdf = gpd.GeoDataFrame(edges)
    routes_gdf.plot(ax=ax, color='gray', linewidth=0.7, alpha=0.75)

    # Finalize plot
    plt.title("Communities in the Network on Geographic Map", fontsize=16)
    plt.axis("off")
    plt.show()

partition = detect_communities(undirected_G)
base_map_gdf = gpd.read_file('japan.geojson')
plot_communities_on_map(undirected_G, partition, base_map_gdf)

# %%
undirected_G.number_of_nodes()
# Out:
# 789

# %%
import networkx as nx

def find_minimal_cut_nodes(G):
    """
    Finds a minimal set of nodes whose removal disconnects the graph.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        cut_nodes (set): Minimal set of nodes to remove to divide the graph into two components.
    """
    # Use NetworkX's built-in function to find the minimum node cut
    cut_nodes = nx.minimum_node_cut(G)
    return cut_nodes

# Example Usage:
if __name__ == "__main__":
    # Create an example graph
    G = undirected_G
    
    # Ensure the graph is connected
    if not nx.is_connected(G):
        print("Graph is not connected. Cannot find a cut that splits it into two components.")
    else:
        # Find minimal cut nodes
        cut_nodes = find_minimal_cut_nodes(G)
        print(f"Minimal set of nodes to remove: {cut_nodes}")

        # Visualize the graph and the critical nodes
        pos = nx.spring_layout(G, k=0.15, seed=42)
        nx.draw(G, pos, with_labels=False, node_color="lightblue", node_size=50)
        nx.draw_networkx_nodes(G, pos, nodelist=cut_nodes, node_color="red", node_size=200)
        plt.title("Graph with Critical Nodes Highlighted")
        plt.show()
# Out:
# Graph is not connected. Cannot find a cut that splits it into two components.

# %%
def plot_minimal_cut_nodes_on_map(G, cut_nodes, base_map_gdf):
    """
    Overlays the graph and minimal cut nodes on a geographic map.

    Parameters:
        G (networkx.Graph): The input graph.
        cut_nodes (set): Nodes that are part of the minimal cut.
        base_map_gdf (GeoDataFrame): The geographic base map.
    """
    base_map_gdf['color'] = base_map_gdf.index % 10
    # Create GeoDataFrame for nodes
    nodes = []
    for node, data in G.nodes(data=True):
        if 'latitude' in data and 'longitude' in data:
            lat = float(data['latitude'])
            lon = float(data['longitude'])
            is_cut = node in cut_nodes
            nodes.append({'id': node, 'geometry': Point(lon, lat), 'is_cut': is_cut})

    nodes_gdf = gpd.GeoDataFrame(nodes)

    # Create GeoDataFrame for edges
    edges = []
    for u, v in G.edges():
        u_data = G.nodes[u]
        v_data = G.nodes[v]
        if 'latitude' in u_data and 'longitude' in u_data and 'latitude' in v_data and 'longitude' in v_data:
            line = LineString([
                Point(float(u_data['longitude']), float(u_data['latitude'])),
                Point(float(v_data['longitude']), float(v_data['latitude']))
            ])
            edges.append({'geometry': line})

    edges_gdf = gpd.GeoDataFrame(edges)

    # Plot base map
    fig, ax = plt.subplots(figsize=(15, 15))
    base_map_gdf.plot(column='color', cmap='tab20', legend=False, ax=ax, alpha=0.3, edgecolor='black')

    # Plot edges
    edges_gdf.plot(ax=ax, color='gray', linewidth=0.5, alpha=0.7, label='Train Routes')

    # Plot nodes
    nodes_gdf[~nodes_gdf['is_cut']].plot(
        ax=ax, color='blue', markersize=50, label='Other Nodes'
    )
    nodes_gdf[nodes_gdf['is_cut']].plot(
        ax=ax, color='red', markersize=100, label='Cut Nodes'
    )

    # Finalize plot
    plt.title("Minimal Cut Nodes on Geographic Map", fontsize=16)
    plt.legend(loc='upper right')
    plt.axis("off")
    plt.show()

# Example Usage
if __name__ == "__main__":
    # Load base map
    base_map_gdf = gpd.read_file('japan.geojson')

    # Ensure the graph is connected
    if not nx.is_connected(undirected_G):
        print("Graph is not connected. Cannot find a cut that splits it into two components.")
    else:
        # Find minimal cut nodes
        cut_nodes = find_minimal_cut_nodes(undirected_G)
        print(f"Minimal set of nodes to remove: {cut_nodes}")

        # Plot minimal cut nodes on the map
        plot_minimal_cut_nodes_on_map(undirected_G, cut_nodes, base_map_gdf)
# Out:
# Graph is not connected. Cannot find a cut that splits it into two components.

# %%
import networkx as nx
import matplotlib.pyplot as plt

def find_minimal_cut_nodes(G):
    """
    Finds a minimal set of nodes whose removal disconnects the graph.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        cut_nodes (set): Minimal set of nodes to remove to divide the graph into two components.
    """
    # Use NetworkX's built-in function to find the minimum node cut
    cut_nodes = nx.minimum_node_cut(G)
    return cut_nodes

def plot_graph_components(G, components, title):
    """
    Plots each connected component of the graph.

    Parameters:
        G (networkx.Graph): The original graph.
        components (list): List of connected components (subgraphs).
        title (str): Title for the plot.
    """
    plt.figure(figsize=(12, 6))
    for i, component in enumerate(components):
        pos = nx.spring_layout(component, seed=42)  # Use spring layout for spread
        nx.draw(
            component,
            pos,
            with_labels=False,
            node_size=300,
            node_color=f"C{i}",  # Different color for each component
            edge_color="gray",

        )
    plt.title(title)
    plt.show()

# Main script
if __name__ == "__main__":
    # Create an example graph
    G = undirected_G

    # Ensure the graph is connected
    if not nx.is_connected(G):
        print("Graph is not connected. Cannot find a cut that splits it into two components.")
    else:
        # Find minimal cut nodes
        cut_nodes = find_minimal_cut_nodes(G)
        print(f"Minimal set of nodes to remove: {cut_nodes}")

        # Remove cut nodes and get the connected components
        G_after_cut = G.copy()
        G_after_cut.remove_nodes_from(cut_nodes)
        components = [G_after_cut.subgraph(c).copy() for c in nx.connected_components(G_after_cut)]

        # Plot the original graph with critical nodes
        pos = nx.spring_layout(G, seed=42)
        plt.figure(figsize=(10, 8))
        nx.draw(
            G,
            pos,
            with_labels=False,
            node_color="lightblue",
            node_size=300,
            edge_color="gray"
        )
        nx.draw_networkx_nodes(
            G,
            pos,
            nodelist=cut_nodes,
            node_color="red",
            node_size=500
        )
        plt.title("Original Graph with Critical Nodes Highlighted")
        plt.show()

        # Plot each connected component separately
        plot_graph_components(G_after_cut, components, "Connected Components After Removing Critical Nodes")
# Out:
# Graph is not connected. Cannot find a cut that splits it into two components.

# %%
import networkx as nx
from shapely.geometry import Point, LineString
import geopandas as gpd
import matplotlib.pyplot as plt

def plot_graph_components_on_map(G, cut_nodes, base_map_path):
    """
    Plots the graph components after removing critical nodes over a geographic map.

    Parameters:
        G (networkx.Graph): The input graph.
        cut_nodes (set): Minimal set of nodes to remove.
        base_map_path (str): Path to the base map GeoJSON file.
    """
    # Load base map
    base_map_gdf = gpd.read_file(base_map_path)
    base_map_gdf['color'] = base_map_gdf.index % 10  # Add color column inside the function

    # Create GeoDataFrame for nodes
    nodes = []
    for node, data in G.nodes(data=True):
        if 'latitude' in data and 'longitude' in data:
            lat = float(data['latitude'])
            lon = float(data['longitude'])
            is_cut = node in cut_nodes
            nodes.append({'id': node, 'geometry': Point(lon, lat), 'is_cut': is_cut})

    nodes_gdf = gpd.GeoDataFrame(nodes)

    # Create GeoDataFrame for edges
    edges = []
    for u, v in G.edges():
        u_data = G.nodes[u]
        v_data = G.nodes[v]
        if 'latitude' in u_data and 'longitude' in u_data and 'latitude' in v_data and 'longitude' in v_data:
            line = LineString([
                Point(float(u_data['longitude']), float(u_data['latitude'])),
                Point(float(v_data['longitude']), float(v_data['latitude']))
            ])
            edges.append({'geometry': line})
    edges_gdf = gpd.GeoDataFrame(edges)

    # Plot the base map
    fig, ax = plt.subplots(figsize=(15, 15))
    base_map_gdf.plot(column='color', cmap='tab20', legend=False, ax=ax, alpha=0.3, edgecolor='black')

    # Plot edges
    edges_gdf.plot(ax=ax, color='gray', linewidth=0.5, alpha=0.7, label='Train Routes')

    # Plot nodes
    nodes_gdf[~nodes_gdf['is_cut']].plot(
        ax=ax, color='blue', markersize=50, label='Other Nodes'
    )
    nodes_gdf[nodes_gdf['is_cut']].plot(
        ax=ax, color='red', markersize=100, label='Cut Nodes'
    )

    # Finalize plot
    plt.title("Graph Components and Critical Nodes on Geographic Map", fontsize=16)
    plt.legend(loc='upper right')
    plt.axis("off")
    plt.show()

# Main script
if __name__ == "__main__":
    # Define the base map path
    base_map_path = 'japan.geojson'

    # Create the graph
    G = undirected_G

    # Ensure the graph is connected
    if not nx.is_connected(G):
        print("Graph is not connected. Cannot find a cut that splits it into two components.")
    else:
        # Find minimal cut nodes
        cut_nodes = find_minimal_cut_nodes(G)
        print(f"Minimal set of nodes to remove: {cut_nodes}")

        # Remove cut nodes and get the connected components
        G_after_cut = G.copy()
        G_after_cut.remove_nodes_from(cut_nodes)
        components = [G_after_cut.subgraph(c).copy() for c in nx.connected_components(G_after_cut)]

        # Plot the original graph with critical nodes on the map
        plot_graph_components_on_map(G, cut_nodes, base_map_path)
# Out:
# Graph is not connected. Cannot find a cut that splits it into two components.

# %%
import networkx as nx
import matplotlib.pyplot as plt

def find_minimal_cut_nodes(G):
    """
    Finds a minimal set of nodes whose removal disconnects the graph.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        cut_nodes (set): Minimal set of nodes to remove to divide the graph into two components.
    """
    return nx.minimum_node_cut(G)

def plot_components_separately(G, components, cut_nodes, original_positions):
    """
    Plots the connected components of the graph on separate sides (left and right).

    Parameters:
        G (networkx.Graph): The original graph.
        components (list): List of connected components (subgraphs).
        cut_nodes (set): The critical nodes that were removed.
        original_positions (dict): Spring layout positions for the original graph.
    """
    # Modify positions to separate components
    pos = {}
    offset = 2  # Offset to separate the components

    # Assign positions for each component (left and right)
    for i, component in enumerate(components):
        component_pos = nx.spring_layout(component, seed=42)
        for node, position in component_pos.items():
            if i == 0:  # Left component
                pos[node] = (position[0] - offset, position[1])
            elif i == 1:  # Right component
                pos[node] = (position[0] + offset, position[1])

    # Add positions for the cut nodes in the middle
    for node in cut_nodes:
        pos[node] = original_positions[node]

    # Plot the components
    plt.figure(figsize=(12, 6))
    for i, component in enumerate(components):
        nx.draw(
            component,
            pos,
            with_labels=True,
            node_size=100,
            node_color=f"C{i}",  # Different color for each component
            edge_color="gray"
        )

    # Highlight the cut nodes in red
    nx.draw_networkx_nodes(
        G,
        pos,
        nodelist=cut_nodes,
        node_color="red",
        node_size=500,
        label="Cut Nodes"
    )
    plt.title("Connected Components After Removing Critical Nodes (Left and Right)")
    plt.legend(["Component 1", "Component 2", "Cut Nodes"])
    plt.show()

# Main script
if __name__ == "__main__":
    # Create an example graph
    G = undirected_G

    # Ensure the graph is connected
    if not nx.is_connected(G):
        print("Graph is not connected. Cannot find a cut that splits it into two components.")
    else:
        # Find minimal cut nodes
        cut_nodes = find_minimal_cut_nodes(G)
        print(f"Minimal set of nodes to remove: {cut_nodes}")

        # Calculate positions for the original graph before removing cut nodes
        original_positions = nx.spring_layout(G, seed=42, k=.5)

        # Remove cut nodes and get the connected components
        G_after_cut = G.copy()
        G_after_cut.remove_nodes_from(cut_nodes)
        components = [G_after_cut.subgraph(c).copy() for c in nx.connected_components(G_after_cut)]

        # Plot the connected components on separate sides
        plot_components_separately(G_after_cut, components, cut_nodes, original_positions)
# Out:
# Graph is not connected. Cannot find a cut that splits it into two components.

# %%
cut_nodes
# Out:
# {'Natore'}

# %%
nx.minimum_node_cut(components[1])
# Out:
# {'Parbatipur'}

# %%
def find_all_cut_nodes_of_size_1(G : nx.Graph):
    """
    Recursively finds all cut nodes of size 1 in a graph.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        cut_nodes (set): Set of all cut nodes of
    """
    cut_nodes = set()
    for node in G.nodes:
        G_copy = G.copy()
        G_copy.remove_node(node)
        if not nx.is_connected(G_copy):
            cut_nodes.add(node)
    return cut_nodes

# %%
size_1_cutnodes = find_all_cut_nodes_of_size_1(undirected_G)

# %%
pos = nx.kamada_kawai_layout(undirected_G)
nx.draw(
    undirected_G,
    pos,
    with_labels=False,
    node_color="lightblue",
    node_size=30,
    edge_color="gray",
    alpha=0.7
)
nx.draw_networkx_nodes(
    undirected_G,
    pos,
    nodelist=size_1_cutnodes,
    node_color="red",
    node_size=40
)

# %%
import networkx as nx
from shapely.geometry import Point, LineString
import geopandas as gpd
import matplotlib.pyplot as plt


def plot_graph_with_cut_nodes_on_map(G, size_1_cutnodes, base_map_path):
    """
    Plots the graph on a geographic map with size-1 cut nodes highlighted.

    Parameters:
        G (networkx.Graph): The input graph.
        size_1_cutnodes (list): List of size-1 cut nodes.
        base_map_path (str): Path to the base map GeoJSON file.
    """
    # Load base map
    base_map_gdf = gpd.read_file(base_map_path)
    base_map_gdf['color'] = base_map_gdf.index % 10  # Add color column inside the function

    # Create GeoDataFrame for nodes
    nodes = []
    for node, data in G.nodes(data=True):
        if 'latitude' in data and 'longitude' in data:
            lat = float(data['latitude'])
            lon = float(data['longitude'])
            is_cut = node in size_1_cutnodes
            nodes.append({'id': node, 'geometry': Point(lon, lat), 'is_cut': is_cut})

    nodes_gdf = gpd.GeoDataFrame(nodes)

    # Create GeoDataFrame for edges
    edges = []
    for u, v in G.edges():
        u_data = G.nodes[u]
        v_data = G.nodes[v]
        if 'latitude' in u_data and 'longitude' in u_data and 'latitude' in v_data and 'longitude' in v_data:
            line = LineString([
                Point(float(u_data['longitude']), float(u_data['latitude'])),
                Point(float(v_data['longitude']), float(v_data['latitude']))
            ])
            edges.append({'geometry': line})
    edges_gdf = gpd.GeoDataFrame(edges)

    # Plot the base map
    fig, ax = plt.subplots(figsize=(15, 15))
    base_map_gdf.plot(column='color', cmap='tab20', legend=False, ax=ax, alpha=0.3, edgecolor='black')

    # Plot edges
    edges_gdf.plot(ax=ax, color='gray', linewidth=0.5, alpha=0.7, label='Train Routes')

    # Plot nodes
    nodes_gdf[~nodes_gdf['is_cut']].plot(
        ax=ax, color='blue', markersize=30, label='Other Nodes'
    )
    nodes_gdf[nodes_gdf['is_cut']].plot(
        ax=ax, color='red', markersize=40, label='Size-1 Cut Nodes'
    )

    # Finalize plot
    plt.title("Graph with Size-1 Cut Nodes on Geographic Map", fontsize=16)
    plt.legend(loc='upper right')
    plt.axis("off")
    plt.show()

# Main script
if __name__ == "__main__":
    # Define the base map path
    base_map_path = 'japan.geojson'

    # Create the graph
    G = undirected_G

    # Find size-1 cut nodes
    size_1_cutnodes = find_all_cut_nodes_of_size_1(G)

    # Plot the graph with size-1 cut nodes on the map
    plot_graph_with_cut_nodes_on_map(G, size_1_cutnodes, base_map_path)
# Out:
# /tmp/ipykernel_1978758/3177263167.py:52: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   nodes_gdf[~nodes_gdf['is_cut']].plot(

# %%
import networkx as nx
import matplotlib.pyplot as plt

def find_cut_edges(G):
    """
    Finds all cut edges (bridges) in the graph.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        list: List of tuples representing the cut edges.
    """
    return list(nx.bridges(G))

def plot_graph_with_cut_edges(G, cut_edges):
    """
    Plots the graph, highlighting the cut edges in red.

    Parameters:
        G (networkx.Graph): The input graph.
        cut_edges (list): List of cut edges.
    """
    pos = nx.kamada_kawai_layout(G)  # Generate layout positions for nodes

    # Draw the graph with default edge colors
    plt.figure(figsize=(10, 8))
    nx.draw(
        G,
        pos,
        with_labels=False,
        node_size=50,
        edge_color="gray",
        node_color="lightblue"
    )

    # Highlight cut edges in red
    nx.draw_networkx_edges(
        G,
        pos,
        edgelist=cut_edges,
        edge_color="red",
        width=2.5,
        label="Cut Edges"
    )

    plt.title("Graph with Cut Edges Highlighted")
    plt.legend(["Nodes", "Cut Edges"], loc="upper left")
    plt.show()

# Main script
if __name__ == "__main__":
    # Create an example graph
    G = undirected_G

    # Ensure the graph is connected
    if nx.is_connected(G):
        # Find the cut edges
        cut_edges = find_cut_edges(G)
        print(f"Cut Edges (Bridges): {cut_edges}")

        # Plot the graph with cut edges highlighted
        plot_graph_with_cut_edges(G, cut_edges)
    else:
        print("The graph is not connected. No cut edges exist.")
# Out:
# The graph is not connected. No cut edges exist.

# %%
import networkx as nx
from shapely.geometry import Point, LineString
import geopandas as gpd
import matplotlib.pyplot as plt


def plot_graph_with_cut_edges_on_map(G, cut_edges, base_map_path):
    """
    Plots the graph on a geographic map, highlighting the cut edges in red.

    Parameters:
        G (networkx.Graph): The input graph.
        cut_edges (list): List of cut edges.
        base_map_path (str): Path to the base map GeoJSON file.
    """
    # Load base map
    base_map_gdf = gpd.read_file(base_map_path)
    base_map_gdf['color'] = base_map_gdf.index % 10  # Add color column inside the function

    # Create GeoDataFrame for nodes
    nodes = []
    for node, data in G.nodes(data=True):
        if 'latitude' in data and 'longitude' in data:
            lat = float(data['latitude'])
            lon = float(data['longitude'])
            nodes.append({'id': node, 'geometry': Point(lon, lat)})

    nodes_gdf = gpd.GeoDataFrame(nodes)

    # Create GeoDataFrame for edges
    edges = []
    for u, v in G.edges():
        u_data = G.nodes[u]
        v_data = G.nodes[v]
        if 'latitude' in u_data and 'longitude' in u_data and 'latitude' in v_data and 'longitude' in v_data:
            line = LineString([
                Point(float(u_data['longitude']), float(u_data['latitude'])),
                Point(float(v_data['longitude']), float(v_data['latitude']))
            ])
            is_cut = (u, v) in cut_edges or (v, u) in cut_edges
            edges.append({'geometry': line, 'is_cut': is_cut})

    edges_gdf = gpd.GeoDataFrame(edges)

    # Plot the base map
    fig, ax = plt.subplots(figsize=(15, 15))
    base_map_gdf.plot(column='color', cmap='tab20', legend=False, ax=ax, alpha=0.3, edgecolor='black')

    # Plot edges
    edges_gdf[~edges_gdf['is_cut']].plot(
        ax=ax, color='gray', linewidth=0.5, alpha=0.7, label='Other Edges'
    )
    edges_gdf[edges_gdf['is_cut']].plot(
        ax=ax, color='red', linewidth=2, label='Cut Edges'
    )

    # Plot nodes
    nodes_gdf.plot(
        ax=ax, color='lightblue', markersize=50, label='Nodes'
    )

    # Finalize plot
    plt.title("Graph with Cut Edges Highlighted on Geographic Map", fontsize=16)
    plt.legend(loc='upper right')
    plt.axis("off")
    plt.show()

# Main script
if __name__ == "__main__":
    # Define the base map path
    base_map_path = 'japan.geojson'

    # Create the graph
    G = undirected_G

    # Ensure the graph is connected
    if nx.is_connected(G):
        # Find the cut edges
        cut_edges = find_cut_edges(G)
        print(f"Cut Edges (Bridges): {cut_edges}")

        # Plot the graph with cut edges highlighted on the map
        plot_graph_with_cut_edges_on_map(G, cut_edges, base_map_path)
    else:
        print("The graph is not connected. No cut edges exist.")
# Out:
# The graph is not connected. No cut edges exist.

# %%
import networkx as nx
import numpy as np

def calculate_degree_correlation(G):
    """
    Calculate the degree correlation coefficients for the network.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        dict: Contains Pearson degree correlation coefficient and correlation exponent.
    """
    # Calculate Pearson degree correlation coefficient
    pearson_coefficient = nx.degree_pearson_correlation_coefficient(G)
    return {
        "pearson_coefficient": pearson_coefficient,
    }

# Example usage
if __name__ == "__main__":
    # Create an example graph
    G = undirected_G

    # Calculate degree correlation coefficients
    results = calculate_degree_correlation(G)

    # Print results
    print(f"Pearson Degree Correlation Coefficient: {results['pearson_coefficient']}")
# Out:
# Pearson Degree Correlation Coefficient: -0.018442367601246096

# %%
knn
# Out:
# {12: 0, 10: 0, 6: 0, 13: 0, 7: 0, 2: 0, 4: 0, 3: 0, 5: 0, 8: 0, 1: 0, 11: 0}

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import defaultdict

def calculate_knn_with_debug(G):
    """
    Calculate k_nn(k), the average degree of neighbors of nodes with degree k, with debugging output.

    Parameters:
        G (networkx.Graph): The input graph.

    Returns:
        knn (dict): A dictionary where keys are degrees (k) and values are k_nn(k).
    """
    # Get the degree of each node
    degrees = dict(G.degree())
    
    # Debugging: Print node degrees
    print("Node degrees:", degrees)
    
    # Dictionaries to store sums and counts
    degree_sum = defaultdict(int)  # Sum of neighbor degrees for nodes of degree k
    degree_count = defaultdict(int)  # Number of nodes with degree k
    
    # Iterate over all nodes
    for node in G.nodes():
        node_degree = degrees[node]  # Degree of the current node
        neighbors = list(G.neighbors(node))
        neighbor_degrees = [degrees[neighbor] for neighbor in neighbors]
        
        # Debugging: Print node and its neighbors' degrees
        print(f"Node {node} (degree {node_degree}) -> Neighbor degrees: {neighbor_degrees}")
        
        # Update sums and counts for the current node degree
        degree_sum[node_degree] += sum(neighbor_degrees)
        degree_count[node_degree] += len(neighbors)
    
    # Calculate k_nn(k)
    knn = {}
    for k in degree_sum:
        if degree_count[k] > 0:
            knn[k] = degree_sum[k] / degree_count[k]
        else:
            knn[k] = 0
    
    # Debugging: Print intermediate results
    print("Degree sum:", dict(degree_sum))
    print("Degree count:", dict(degree_count))
    print("k_nn(k):", knn)
    
    return knn

def plot_knn(knn):
    """
    Plot k_nn(k) vs. k.

    Parameters:
        knn (dict): A dictionary where keys are degrees (k) and values are k_nn(k).
    """
    # Extract k and k_nn(k)
    k_values = sorted(knn.keys())
    knn_values = [knn[k] for k in k_values]

    # Plot the function
    plt.figure(figsize=(8, 6))
    plt.plot(k_values, knn_values, marker="o", linestyle="-", color="blue", label=r"$k_{\text{nn}}(k)$")
    # plt.xscale("log")
    # plt.yscale("log")
    plt.xlabel("Degree (k)")
    plt.ylabel(r"Average Neighbor Degree $k_{\text{nn}}(k)$")
    plt.title(r"Degree Correlation Function $k_{\text{nn}}(k)$")
    plt.grid(True, which="both", linestyle="--", linewidth=0.5)
    plt.legend()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Create an example undirected graph
    G = undirected_G  # Scale-free network

    # Calculate k_nn(k)
    knn = calculate_knn_with_debug(G)

    # Plot the results
    plot_knn(knn)
# Out:
# Node degrees: {'Kogota': 2, 'Kami-Wakuya': 2, 'Wakuya': 2, 'Maeyachi': 3, 'Kakeyama': 2, 'Kanomata': 2, 'Sobanokami': 2, 'Ishinomaki': 2, 'Rikuzen-Inai': 2, 'Watanoha': 2, 'Mangokuura': 2, 'Sawada': 2, 'Urashuku': 2, 'Onagawa': 1, 'Sawara': 2, 'Katori': 3, 'Jūnikyō': 2, 'Itako': 2, 'Nobukata': 2, 'Kashimajingū': 2, 'Kashima-Soccer Stadium（Seasonal）': 1, 'Chiba': 2, 'Higashi-Chiba': 2, 'Tsuga': 2, 'Yotsukaidō': 2, 'Monoi': 2, 'Sakura': 3, 'Minami-Shisui': 1, 'Yachimata': 0, 'Narutō': 2, 'Matsuo': 2, 'Yokoshiba': 2, 'Iigura': 2, 'Yōkaichiba': 2, 'Higata': 2, 'Asahi': 2, 'Iioka': 2, 'Kurahashi': 2, 'Saruda': 2, 'Matsugishi': 3, 'Chōshi': 1, 'Chigasaki': 1, 'Kita-Chigasaki': 1, 'Samukawa': 1, 'Miyayama': 2, 'Kurami': 2, 'Kadosawabashi': 2, 'Shake': 2, 'Atsugi': 2, 'Ebina': 2, 'Iriya': 2, 'Sōbudaishita': 2, 'Shimomizo': 2, 'Harataima': 2, 'Banda': 2, 'Kamimizo': 2, 'Minami-Hashimoto': 1, 'Kitaura': 2, 'Rikuzen-Yachi': 2, 'Furukawa': 2, 'Tsukanome': 2, 'Nishi-Furukawa': 2, 'Higashi-Ōsaki': 2, 'Nishi-Ōsaki': 2, 'Iwadeyama': 2, 'Yūbikan': 2, 'Kaminome': 2, 'Ikezuki': 2, 'Kawatabi-Onsen': 2, 'Narukogotenyu': 2, 'Naruko-Onsen': 2, 'Nakayamadaira-Onsen': 2, 'Sakaida': 2, 'Akakura-Onsen': 2, 'Tachikōji': 2, 'Mogami': 2, 'Ōhori': 2, 'Usugi': 2, 'Semi-Onsen': 2, 'Higashi-Nagasawa': 2, 'Nagasawa': 2, 'Minami-Shinjō': 2, 'Shinjō': 2, 'Aomori': 1, 'Aburakawa': 2, 'Tsugaru-Miyata': 2, 'Okunai': 2, 'Hidariseki': 2, 'Ushirogata': 2, 'Nakasawa': 2, 'Yomogita': 2, 'Gōsawa': 2, 'Seheji': 2, 'Kanita': 1, 'Ōdai': 1, 'Tsugaru-Futamata': 2, 'Ōkawadai': 2, 'Imabetsu': 2, 'Tsugaru-Hamana': 2, 'Mimmaya': 1, 'Atami': 1, 'Kinomiya': 2, 'Izu-Taga': 2, 'Ajiro': 2, 'Usami': 2, 'Itō': 1, 'Hama-Kawasaki': 1, 'Odasakae': 2, 'Kawasakishimmachi': 2, 'Hatchōnawate': 2, 'Shitte': 1, 'Hon-Chiba': 2, 'Soga': 3, 'Hamano': 2, 'Yawatajuku': 2, 'Goi': 2, 'Anegasaki': 2, 'Nagaura': 2, 'Sodegaura': 2, 'Iwane': 2, 'Kisarazu': 2, 'Kimitsu': 2, 'Aohori': 2, 'Ōnuki': 2, 'Sanukimachi': 2, 'Kazusa-Minato': 1, 'Hama-Kanaya': 1, 'Hota': 2, 'Awa-Katsuyama': 2, 'Iwai': 2, 'Tomiura': 2, 'Nakofunakata': 2, 'Tateyama': 2, 'Chikura': 0, 'Minamihara': 1, 'Wadaura': 2, 'Emi': 1, 'Awa-Kamogawa': 1, 'Hanamaki': 1, 'Nitanai': 2, 'Shin-Hanamaki': 2, 'Oyamada': 2, 'Tsuchizawa': 2, 'Haruyama': 2, 'Iwanebashi': 2, 'Miyamori': 2, 'Kashiwagidaira': 2, 'Masuzawa': 2, 'Arayamae': 2, 'Iwate-Futsukamachi': 2, 'Ayaori': 2, 'Tōno': 2, 'Aozasa': 2, 'Iwate-Kamigō': 2, 'Hirakura': 2, 'Ashigase': 2, 'Kami-Arisu': 2, 'Rikuchū-Ōhashi': 2, 'Dōsen': 2, 'Matsukura': 2, 'Kosano': 2, 'Kamaishi': 1, 'Shisui': 2, 'Narita': 4, 'Narita Airport Terminal 2・3': 2, 'Narita Airport Terminal 1': 1, 'Jimbohara': 1, 'Shimmachi': 2, 'Kuragano': 3, 'Takasaki': 3, 'Kobuchizawa': 1, 'Kai-Koizumi': 2, 'Kai-Ōizumi': 1, 'Nobeyama': 1, 'Shinano-Kawakami': 2, 'Saku-Hirose': 2, 'Saku-Uminokuchi': 2, 'Umijiri': 2, 'Matsubarako': 2, 'Koumi': 2, 'Managashi': 1, 'Yachiho': 0, 'Haguroshita': 1, 'Aonuma': 2, 'Usuda': 2, 'Tatsuokajō': 2, 'Ōtabe': 2, 'Nakagomi': 2, 'Namezu': 2, 'Kita-Nakagomi': 2, 'Iwamurada': 2, 'Sakudaira': 2, 'Nakasato': 2, 'Misato': 2, 'Mitsuoka': 2, 'Otome': 2, 'Higashi-Komoro': 2, 'Komoro': 1, 'Sendai': 2, 'Tōshōgū': 2, 'Kita-Sendai': 1, 'Tōhoku Fukushi University': 1, 'Kunimi': 2, 'Kuzuoka': 2, 'Rikuzen-Ochiai': 2, 'Ayashi': 2, 'Rikuzen-Shirasawa': 2, 'Kumagane': 2, 'Sakunami': 2, 'Oku-Nikkawa': 2, 'Omoshiroyama-Kōgen': 2, 'Yamadera': 1, 'Uzen-Chitose': 2, 'Kita-Yamagata': 3, 'Yamagata': 1, 'Aizu-Wakamatsu': 1, 'Nanukamachi': 2, 'Nishi-Wakamatsu': 2, 'Aizu-Hongō': 2, 'Aizu-Takada': 2, 'Negishi': 2, 'Niitsuru': 2, 'Wakamiya': 2, 'Aizu-Bange': 2, 'Tōdera': 2, 'Aizu-Sakamoto': 2, 'Aizu-Yanaizu': 2, 'Gōdo': 2, 'Takiya': 2, 'Aizu-Hinohara': 2, 'Aizu-Nishikata': 2, 'Aizu-Miyashita': 1, 'Aizu-Mizunuma': 1, 'Aizu-Nakagawa': 2, 'Aizu-Kawaguchi': 2, 'Honna': 2, 'Aizu-Kosugawa': 2, 'Aizu-Yokota': 2, 'Aizu-Ōshio': 2, 'Aizu-Shiozawa': 2, 'Aizu-Gamō': 2, 'Tadami': 2, 'Ōshirakawa': 2, 'Irihirose': 2, 'Kamijō': 2, 'Echigo-Suhara': 2, 'Uon ...
# Node Kogota (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Wakuya (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakuya (degree 2) -> Neighbor degrees: [2, 3]
# Node Maeyachi (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Kakeyama (degree 2) -> Neighbor degrees: [3, 2]
# Node Kanomata (degree 2) -> Neighbor degrees: [2, 2]
# Node Sobanokami (degree 2) -> Neighbor degrees: [2, 2]
# Node Ishinomaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Inai (degree 2) -> Neighbor degrees: [2, 2]
# Node Watanoha (degree 2) -> Neighbor degrees: [2, 2]
# Node Mangokuura (degree 2) -> Neighbor degrees: [2, 2]
# Node Sawada (degree 2) -> Neighbor degrees: [2, 2]
# Node Urashuku (degree 2) -> Neighbor degrees: [2, 1]
# Node Onagawa (degree 1) -> Neighbor degrees: [2]
# Node Sawara (degree 2) -> Neighbor degrees: [3, 2]
# Node Katori (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Jūnikyō (degree 2) -> Neighbor degrees: [3, 2]
# Node Itako (degree 2) -> Neighbor degrees: [2, 2]
# Node Nobukata (degree 2) -> Neighbor degrees: [2, 2]
# Node Kashimajingū (degree 2) -> Neighbor degrees: [2, 1]
# Node Kashima-Soccer Stadium（Seasonal） (degree 1) -> Neighbor degrees: [2]
# Node Chiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Chiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuga (degree 2) -> Neighbor degrees: [2, 2]
# Node Yotsukaidō (degree 2) -> Neighbor degrees: [2, 2]
# Node Monoi (degree 2) -> Neighbor degrees: [2, 3]
# Node Sakura (degree 3) -> Neighbor degrees: [2, 1, 2]
# Node Minami-Shisui (degree 1) -> Neighbor degrees: [3]
# Node Yachimata (degree 0) -> Neighbor degrees: []
# Node Narutō (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsuo (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokoshiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Iigura (degree 2) -> Neighbor degrees: [2, 2]
# Node Yōkaichiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Higata (degree 2) -> Neighbor degrees: [2, 2]
# Node Asahi (degree 2) -> Neighbor degrees: [2, 2]
# Node Iioka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kurahashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Saruda (degree 2) -> Neighbor degrees: [2, 3]
# Node Matsugishi (degree 3) -> Neighbor degrees: [2, 1, 2]
# Node Chōshi (degree 1) -> Neighbor degrees: [3]
# Node Chigasaki (degree 1) -> Neighbor degrees: [1]
# Node Kita-Chigasaki (degree 1) -> Neighbor degrees: [1]
# Node Samukawa (degree 1) -> Neighbor degrees: [2]
# Node Miyayama (degree 2) -> Neighbor degrees: [1, 2]
# Node Kurami (degree 2) -> Neighbor degrees: [2, 2]
# Node Kadosawabashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shake (degree 2) -> Neighbor degrees: [2, 2]
# Node Atsugi (degree 2) -> Neighbor degrees: [2, 2]
# Node Ebina (degree 2) -> Neighbor degrees: [2, 2]
# Node Iriya (degree 2) -> Neighbor degrees: [2, 2]
# Node Sōbudaishita (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimomizo (degree 2) -> Neighbor degrees: [2, 2]
# Node Harataima (degree 2) -> Neighbor degrees: [2, 2]
# Node Banda (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamimizo (degree 2) -> Neighbor degrees: [2, 1]
# Node Minami-Hashimoto (degree 1) -> Neighbor degrees: [2]
# Node Kitaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Yachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Furukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsukanome (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Furukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Ōsaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Ōsaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwadeyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Yūbikan (degree 2) -> Neighbor degrees: [2, 2]
# Node Kaminome (degree 2) -> Neighbor degrees: [2, 2]
# Node Ikezuki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawatabi-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Narukogotenyu (degree 2) -> Neighbor degrees: [2, 2]
# Node Naruko-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakayamadaira-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Sakaida (degree 2) -> Neighbor degrees: [2, 2]
# Node Akakura-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Tachikōji (degree 2) -> Neighbor degrees: [2, 2]
# Node Mogami (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōhori (degree 2) -> Neighbor degrees: [2, 2]
# Node Usugi (degree 2) -> Neighbor degrees: [2, 2]
# Node Semi-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Nagasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Shinjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Aomori (degree 1) -> Neighbor degrees: [2]
# Node Aburakawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Tsugaru-Miyata (degree 2) -> Neighbor degrees: [2, 2]
# Node Okunai (degree 2) -> Neighbor degrees: [2, 2]
# Node Hidariseki (degree 2) -> Neighbor degrees: [2, 2]
# Node Ushirogata (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Yomogita (degree 2) -> Neighbor degrees: [2, 2]
# Node Gōsawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Seheji (degree 2) -> Neighbor degrees: [2, 1]
# Node Kanita (degree 1) -> Neighbor degrees: [2]
# Node Ōdai (degree 1) -> Neighbor degrees: [2]
# Node Tsugaru-Futamata (degree 2) -> Neighbor degrees: [1, 2]
# Node Ōkawadai (degree 2) -> Neighbor degrees: [2, 2]
# Node Imabetsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsugaru-Hamana (degree 2) -> Neighbor degrees: [2, 1]
# Node Mimmaya (degree 1) -> Neighbor degrees: [2]
# Node Atami (degree 1) -> Neighbor degrees: [2]
# Node Kinomiya (degree 2) -> Neighbor degrees: [1, 2]
# Node Izu-Taga (degree 2) -> Neighbor degrees: [2, 2]
# Node Ajiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Usami (degree 2) -> Neighbor degrees: [2, 1]
# Node Itō (degree 1) -> Neighbor degrees: [2]
# Node Hama-Kawasaki (degree 1) -> Neighbor degrees: [2]
# Node Odasakae (degree 2) -> Neighbor degrees: [1, 2]
# Node Kawasakishimmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hatchōnawate (degree 2) -> Neighbor degrees: [2, 1]
# Node Shitte (degree 1) -> Neighbor degrees: [2]
# Node Hon-Chiba (degree 2) -> Neighbor degrees: [2, 3]
# Node Soga (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Hamano (degree 2) -> Neighbor degrees: [3, 2]
# Node Yawatajuku (degree 2) -> Neighbor degrees: [2, 2]
# Node Goi (degree 2) -> Neighbor degrees: [2, 2]
# Node Anegasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Sodegaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwane (degree 2) -> Neighbor degrees: [2, 2]
# Node Kisarazu (degree 2) -> Neighbor degrees: [2, 2]
# Node Kimitsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Aohori (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōnuki (degree 2) -> Neighbor degrees: [2, 2]
# Node Sanukimachi (degree 2) -> Neighbor degrees: [2, 1]
# Node Kazusa-Minato (degree 1) -> Neighbor degrees: [2]
# Node Hama-Kanaya (degree 1) -> Neighbor degrees: [2]
# Node Hota (degree 2) -> Neighbor degrees: [1, 2]
# Node Awa-Katsuyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwai (degree 2) -> Neighbor degrees: [2, 2]
# Node Tomiura (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakofunakata (degree 2) -> Neighbor degrees: [2, 2]
# Node Tateyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Chikura (degree 0) -> Neighbor degrees: []
# Node Minamihara (degree 1) -> Neighbor degrees: [2]
# Node Wadaura (degree 2) -> Neighbor degrees: [1, 1]
# Node Emi (degree 1) -> Neighbor degrees: [2]
# Node Awa-Kamogawa (degree 1) -> Neighbor degrees: [2]
# Node Hanamaki (degree 1) -> Neighbor degrees: [2]
# Node Nitanai (degree 2) -> Neighbor degrees: [1, 2]
# Node Shin-Hanamaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Oyamada (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuchizawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Haruyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwanebashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Miyamori (degree 2) -> Neighbor degrees: [2, 2]
# Node Kashiwagidaira (degree 2) -> Neighbor degrees: [2, 2]
# Node Masuzawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Arayamae (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwate-Futsukamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Ayaori (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōno (degree 2) -> Neighbor degrees: [2, 2]
# Node Aozasa (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwate-Kamigō (degree 2) -> Neighbor degrees: [2, 2]
# Node Hirakura (degree 2) -> Neighbor degrees: [2, 2]
# Node Ashigase (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Arisu (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Ōhashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Dōsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsukura (degree 2) -> Neighbor degrees: [2, 2]
# Node Kosano (degree 2) -> Neighbor degrees: [2, 1]
# Node Kamaishi (degree 1) -> Neighbor degrees: [2]
# Node Shisui (degree 2) -> Neighbor degrees: [3, 4]
# Node Narita (degree 4) -> Neighbor degrees: [2, 2, 2, 2]
# Node Narita Airport Terminal 2・3 (degree 2) -> Neighbor degrees: [4, 1]
# Node Narita Airport Terminal 1 (degree 1) -> Neighbor degrees: [2]
# Node Jimbohara (degree 1) -> Neighbor degrees: [2]
# Node Shimmachi (degree 2) -> Neighbor degrees: [1, 3]
# Node Kuragano (degree 3) -> Neighbor degrees: [2, 3, 2]
# Node Takasaki (degree 3) -> Neighbor degrees: [3, 1, 2]
# Node Kobuchizawa (degree 1) -> Neighbor degrees: [2]
# Node Kai-Koizumi (degree 2) -> Neighbor degrees: [1, 1]
# Node Kai-Ōizumi (degree 1) -> Neighbor degrees: [2]
# Node Nobeyama (degree 1) -> Neighbor degrees: [2]
# Node Shinano-Kawakami (degree 2) -> Neighbor degrees: [1, 2]
# Node Saku-Hirose (degree 2) -> Neighbor degrees: [2, 2]
# Node Saku-Uminokuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Umijiri (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsubarako (degree 2) -> Neighbor degrees: [2, 2]
# Node Koumi (degree 2) -> Neighbor degrees: [2, 1]
# Node Managashi (degree 1) -> Neighbor degrees: [2]
# Node Yachiho (degree 0) -> Neighbor degrees: []
# Node Haguroshita (degree 1) -> Neighbor degrees: [2]
# Node Aonuma (degree 2) -> Neighbor degrees: [1, 2]
# Node Usuda (degree 2) -> Neighbor degrees: [2, 2]
# Node Tatsuokajō (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōtabe (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakagomi (degree 2) -> Neighbor degrees: [2, 2]
# Node Namezu (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Nakagomi (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwamurada (degree 2) -> Neighbor degrees: [2, 2]
# Node Sakudaira (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakasato (degree 2) -> Neighbor degrees: [2, 2]
# Node Misato (degree 2) -> Neighbor degrees: [2, 2]
# Node Mitsuoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Otome (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Komoro (degree 2) -> Neighbor degrees: [2, 1]
# Node Komoro (degree 1) -> Neighbor degrees: [2]
# Node Sendai (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōshōgū (degree 2) -> Neighbor degrees: [2, 1]
# Node Kita-Sendai (degree 1) -> Neighbor degrees: [2]
# Node Tōhoku Fukushi University (degree 1) -> Neighbor degrees: [2]
# Node Kunimi (degree 2) -> Neighbor degrees: [1, 2]
# Node Kuzuoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Ochiai (degree 2) -> Neighbor degrees: [2, 2]
# Node Ayashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Shirasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kumagane (degree 2) -> Neighbor degrees: [2, 2]
# Node Sakunami (degree 2) -> Neighbor degrees: [2, 2]
# Node Oku-Nikkawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Omoshiroyama-Kōgen (degree 2) -> Neighbor degrees: [2, 1]
# Node Yamadera (degree 1) -> Neighbor degrees: [2]
# Node Uzen-Chitose (degree 2) -> Neighbor degrees: [2, 3]
# Node Kita-Yamagata (degree 3) -> Neighbor degrees: [2, 1, 2]
# Node Yamagata (degree 1) -> Neighbor degrees: [3]
# Node Aizu-Wakamatsu (degree 1) -> Neighbor degrees: [2]
# Node Nanukamachi (degree 2) -> Neighbor degrees: [1, 2]
# Node Nishi-Wakamatsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Hongō (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Takada (degree 2) -> Neighbor degrees: [2, 2]
# Node Negishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Niitsuru (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakamiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Bange (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōdera (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Sakamoto (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Yanaizu (degree 2) -> Neighbor degrees: [2, 2]
# Node Gōdo (degree 2) -> Neighbor degrees: [2, 2]
# Node Takiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Hinohara (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Nishikata (degree 2) -> Neighbor degrees: [2, 1]
# Node Aizu-Miyashita (degree 1) -> Neighbor degrees: [2]
# Node Aizu-Mizunuma (degree 1) -> Neighbor degrees: [2]
# Node Aizu-Nakagawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Aizu-Kawaguchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Honna (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Kosugawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Yokota (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Ōshio (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Shiozawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Gamō (degree 2) -> Neighbor degrees: [2, 2]
# Node Tadami (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōshirakawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Irihirose (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamijō (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Suhara (degree 2) -> Neighbor degrees: [2, 2]
# Node Uonuma-Tanaka (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Hirose (degree 2) -> Neighbor degrees: [2, 2]
# Node Yabukami (degree 2) -> Neighbor degrees: [2, 1]
# Node Koide (degree 1) -> Neighbor degrees: [2]
# Node Ōami (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukutawara (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōgane (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumyō (degree 2) -> Neighbor degrees: [2, 2]
# Node Takasakitonyamachi (degree 1) -> Neighbor degrees: [3]
# Node Shim-Maebashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Maebashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Maebashiōshima (degree 2) -> Neighbor degrees: [2, 2]
# Node Komagata (degree 2) -> Neighbor degrees: [2, 2]
# Node Isesaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kunisada (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwajuku (degree 2) -> Neighbor degrees: [2, 2]
# Node Kiryū (degree 2) -> Neighbor degrees: [2, 2]
# Node Omata (degree 2) -> Neighbor degrees: [2, 2]
# Node Yamamae (degree 2) -> Neighbor degrees: [2, 2]
# Node Ashikaga (degree 2) -> Neighbor degrees: [2, 2]
# Node Ashikaga Flower Park (degree 2) -> Neighbor degrees: [2, 2]
# Node Tomita (degree 2) -> Neighbor degrees: [2, 2]
# Node Sano (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwafune (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōhirashita (degree 2) -> Neighbor degrees: [2, 2]
# Node Tochigi (degree 2) -> Neighbor degrees: [2, 2]
# Node Omoigawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Oyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Hachinohe (degree 1) -> Neighbor degrees: [2]
# Node Naganawashiro (degree 2) -> Neighbor degrees: [1, 2]
# Node Hon-Hachinohe (degree 2) -> Neighbor degrees: [2, 2]
# Node Konakano (degree 2) -> Neighbor degrees: [2, 1]
# Node Mutsu-Minato (degree 1) -> Neighbor degrees: [2]
# Node Same (degree 1) -> Neighbor degrees: [2]
# Node Mutsu-Shirahama (degree 2) -> Neighbor degrees: [1, 2]
# Node Tanesashikaigan (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōkuki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanehama (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōja (degree 2) -> Neighbor degrees: [2, 2]
# Node Hashikami (degree 2) -> Neighbor degrees: [2, 2]
# Node Kadonohama (degree 2) -> Neighbor degrees: [2, 2]
# Node Hiranai (degree 2) -> Neighbor degrees: [2, 2]
# Node Taneichi (degree 2) -> Neighbor degrees: [2, 2]
# Node Tamagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shukunohe (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Yagi (degree 2) -> Neighbor degrees: [2, 2]
# Node Uge (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Nakano (degree 2) -> Neighbor degrees: [2, 2]
# Node Samuraihama (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Natsui (degree 2) -> Neighbor degrees: [2, 1]
# Node Kuji (degree 1) -> Neighbor degrees: [2]
# Node Abiko (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Abiko (degree 2) -> Neighbor degrees: [1, 1]
# Node Kohoku (degree 1) -> Neighbor degrees: [2]
# Node Fusa (degree 1) -> Neighbor degrees: [1]
# Node Kioroshi (degree 1) -> Neighbor degrees: [1]
# Node Ajiki (degree 1) -> Neighbor degrees: [2]
# Node Shimōsa-Manzaki (degree 2) -> Neighbor degrees: [4, 1]
# Node Morioka (degree 3) -> Neighbor degrees: [2, 2, 3]
# Node Kami-Morioka (degree 2) -> Neighbor degrees: [3, 2]
# Node Yamagishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Yonai (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuzakai (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsukusa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawauchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakoishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Kawai (degree 2) -> Neighbor degrees: [2, 2]
# Node Haratai (degree 2) -> Neighbor degrees: [2, 2]
# Node Moichi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hikime (degree 2) -> Neighbor degrees: [2, 2]
# Node Kebaraichi (degree 2) -> Neighbor degrees: [2, 2]
# Node Sentoku (degree 2) -> Neighbor degrees: [2, 1]
# Node Miyako (degree 1) -> Neighbor degrees: [2]
# Node Kitakami (degree 0) -> Neighbor degrees: []
# Node Ezuriko (degree 1) -> Neighbor degrees: [2]
# Node Fujine (degree 2) -> Neighbor degrees: [1, 2]
# Node Tatekawame (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokokawame (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakasennin (degree 2) -> Neighbor degrees: [2, 2]
# Node Yudakinshūko (degree 2) -> Neighbor degrees: [2, 2]
# Node Hotto-Yuda (degree 2) -> Neighbor degrees: [2, 2]
# Node Yuda-Kōgen (degree 2) -> Neighbor degrees: [2, 2]
# Node Kurosawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Komatsukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Ainono (degree 2) -> Neighbor degrees: [2, 1]
# Node Yokote (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Noshiro (degree 1) -> Neighbor degrees: [2]
# Node Noshiro (degree 2) -> Neighbor degrees: [1, 2]
# Node Mukai-Noshiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Noshiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Torigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Sawame (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Hachimori (degree 2) -> Neighbor degrees: [2, 2]
# Node Hachimori (degree 2) -> Neighbor degrees: [2, 2]
# Node Takinoma (degree 2) -> Neighbor degrees: [2, 2]
# Node Akitashirakami (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwadate (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōmagoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shirakamidaketozanguchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsukami (degree 2) -> Neighbor degrees: [2, 2]
# Node Jūniko (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Iwasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Sawabe (degree 2) -> Neighbor degrees: [2, 2]
# Node WeSPa Tsubakiyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Henashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokoiso (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Hiroto (degree 2) -> Neighbor degrees: [2, 2]
# Node Oirase (degree 2) -> Neighbor degrees: [2, 2]
# Node Todoroki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kasose (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōdose (degree 2) -> Neighbor degrees: [2, 2]
# Node Senjōjiki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Kanegasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Yanagita (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Akaishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Ajigasawa (degree 2) -> Neighbor degrees: [2, 1]
# Node Narusawa (degree 1) -> Neighbor degrees: [2]
# Node Mutsu-Morita (degree 1) -> Neighbor degrees: [2]
# Node Nakata (degree 2) -> Neighbor degrees: [1, 2]
# Node Kizukuri (degree 2) -> Neighbor degrees: [2, 2]
# Node Goshogawara (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Tsuruda (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsurudomari (degree 2) -> Neighbor degrees: [2, 1]
# Node Itayanagi (degree 1) -> Neighbor degrees: [2]
# Node Fujisaki (degree 1) -> Neighbor degrees: [2]
# Node Kawabe (degree 2) -> Neighbor degrees: [1, 2]
# Node Naijoshi (degree 2) -> Neighbor degrees: [2, 1]
# Node Hirosaki (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Kanai (degree 2) -> Neighbor degrees: [3, 2]
# Node Uzen-Yamabe (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Kanezawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Nagasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Sagae (degree 2) -> Neighbor degrees: [2, 2]
# Node Sagae (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Sagae (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Takamatsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibahashi (degree 2) -> Neighbor degrees: [2, 1]
# Node Aterazawa (degree 1) -> Neighbor degrees: [2]
# Node Iwaki (degree 1) -> Neighbor degrees: [2]
# Node Akai (degree 2) -> Neighbor degrees: [1, 2]
# Node Ogawagō (degree 2) -> Neighbor degrees: [2, 2]
# Node Eda (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawamae (degree 2) -> Neighbor degrees: [2, 2]
# Node Natsui (degree 2) -> Neighbor degrees: [2, 2]
# Node Ononiimachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kammata (degree 2) -> Neighbor degrees: [2, 2]
# Node Sugaya (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōgoe (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwaki-Tokiwa (degree 2) -> Neighbor degrees: [2, 2]
# Node Funehiki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanameta (degree 2) -> Neighbor degrees: [2, 2]
# Node Miharu (degree 2) -> Neighbor degrees: [2, 2]
# Node Mōgi (degree 2) -> Neighbor degrees: [2, 1]
# Node Kōriyama (degree 1) -> Neighbor degrees: [2]
# Node Matsumoto (degree 1) -> Neighbor degrees: [2]
# Node Kita-Matsumoto (degree 2) -> Neighbor degrees: [1, 2]
# Node Shimauchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimatakamatsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Azusabashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hitoichiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakagaya (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Toyoshina (degree 2) -> Neighbor degrees: [2, 2]
# Node Toyoshina (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakuyacho (degree 2) -> Neighbor degrees: [2, 2]
# Node Hotaka (degree 2) -> Neighbor degrees: [2, 2]
# Node Ariake (degree 2) -> Neighbor degrees: [2, 2]
# Node Azumi-Oiwake (degree 2) -> Neighbor degrees: [2, 2]
# Node Hosono (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Hosono (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Matsukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Azumi-Kutsukake (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Tokiwa (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Ōmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Ōmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Ōmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Kizaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Inao (degree 2) -> Neighbor degrees: [2, 2]
# Node Uminokuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yanaba (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Kamishiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamishiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Iimori (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakuba (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Moriue (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakubaōike (degree 2) -> Neighbor degrees: [2, 2]
# Node Chikuni (degree 2) -> Neighbor degrees: [2, 1]
# Node Minami-Otari (degree 1) -> Neighbor degrees: [2]
# Node Utsunomiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Okamoto (degree 2) -> Neighbor degrees: [2, 2]
# Node Hōshakuji (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimotsuke-Hanaoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Niita (degree 2) -> Neighbor degrees: [2, 2]
# Node Kōnoyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōgane (degree 2) -> Neighbor degrees: [2, 1]
# Node Kobana (degree 1) -> Neighbor degrees: [2]
# Node Karasuyama (degree 0) -> Neighbor degrees: []
# Node Yahiko (degree 1) -> Neighbor degrees: [2]
# Node Yahagi (degree 2) -> Neighbor degrees: [1, 4]
# Node Yoshida (degree 4) -> Neighbor degrees: [2, 2, 2, 2]
# Node Nishi-Tsubame (degree 2) -> Neighbor degrees: [4, 2]
# Node Tsubame (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsubamesanjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Sanjō (degree 2) -> Neighbor degrees: [2, 3]
# Node Higashi-Sanjō (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Kita-Takasaki (degree 2) -> Neighbor degrees: [3, 2]
# Node Gumma-Yawata (degree 2) -> Neighbor degrees: [2, 2]
# Node Annaka (degree 2) -> Neighbor degrees: [2, 2]
# Node Isobe (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsuida (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Matsuida (degree 2) -> Neighbor degrees: [2, 1]
# Node Yokokawa (degree 1) -> Neighbor degrees: [2]
# Node Niigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Niigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōgata (degree 2) -> Neighbor degrees: [2, 2]
# Node Niizaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Hayadōri (degree 2) -> Neighbor degrees: [2, 2]
# Node Toyosaka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuroyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Sasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Shibata (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibata (degree 2) -> Neighbor degrees: [2, 2]
# Node Kaji (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanazuka (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakajō (degree 2) -> Neighbor degrees: [2, 2]
# Node Hirakida (degree 2) -> Neighbor degrees: [2, 3]
# Node Sakamachi (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Hirabayashi (degree 2) -> Neighbor degrees: [3, 2]
# Node Iwafunemachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Murakami (degree 2) -> Neighbor degrees: [2, 2]
# Node Majima (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Hayakawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuwagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Imagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Kangawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Gatsugi (degree 2) -> Neighbor degrees: [2, 2]
# Node Fuya (degree 2) -> Neighbor degrees: [2, 2]
# Node Nezugaseki (degree 2) -> Neighbor degrees: [2, 2]
# Node Koiwagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Atsumi-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Iragawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kobato (degree 2) -> Neighbor degrees: [2, 2]
# Node Sanze (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Mizusawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Ōyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuruoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Fujishima (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishibukuro (degree 2) -> Neighbor degrees: [2, 3]
# Node Amarume (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Kita-Amarume (degree 2) -> Neighbor degrees: [3, 2]
# Node Sagoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Sakata (degree 2) -> Neighbor degrees: [2, 1]
# Node Sakata (degree 1) -> Neighbor degrees: [2]
# Node Noheji (degree 1) -> Neighbor degrees: [2]
# Node Kita-Noheji (degree 2) -> Neighbor degrees: [1, 2]
# Node Arito (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukkoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Yokohama (degree 2) -> Neighbor degrees: [2, 2]
# Node Arihata (degree 2) -> Neighbor degrees: [2, 2]
# Node Chikagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanayasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Akagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimokita (degree 2) -> Neighbor degrees: [2, 1]
# Node Ōminato (degree 1) -> Neighbor degrees: [2]
# Node Naoetsu (degree 1) -> Neighbor degrees: [2]
# Node Kuroi (degree 2) -> Neighbor degrees: [1, 2]
# Node Saigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Dosokohama (degree 2) -> Neighbor degrees: [2, 2]
# Node Katamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Jōgehama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kakizaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Yoneyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kasashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōmigawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kujiranami (degree 2) -> Neighbor degrees: [2, 3]
# Node Kashiwazaki (degree 3) -> Neighbor degrees: [2, 1, 2]
# Node Ibarame (degree 1) -> Neighbor degrees: [3]
# Node Kitajō (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Hirota (degree 2) -> Neighbor degrees: [1, 2]
# Node Nagatori (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsukayama (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Iwatsuka (degree 2) -> Neighbor degrees: [2, 2]
# Node Raikōji (degree 2) -> Neighbor degrees: [2, 2]
# Node Maekawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Miyauchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagaoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Nagaoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Oshikiri (degree 2) -> Neighbor degrees: [2, 2]
# Node Mitsuke (degree 2) -> Neighbor degrees: [2, 2]
# Node Obiori (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōkōji (degree 2) -> Neighbor degrees: [2, 2]
# Node Sanjō (degree 2) -> Neighbor degrees: [3, 2]
# Node Honai (degree 2) -> Neighbor degrees: [3, 2]
# Node Kamo (degree 2) -> Neighbor degrees: [2, 2]
# Node Hanyūda (degree 2) -> Neighbor degrees: [2, 2]
# Node Tagami (degree 2) -> Neighbor degrees: [2, 2]
# Node Yashiroda (degree 2) -> Neighbor degrees: [2, 2]
# Node Furutsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Niitsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Satsukino (degree 2) -> Neighbor degrees: [2, 2]
# Node Ogikawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kameda (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Ishiyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Kiyokawa (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Kiyokawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Yokota (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Yokota (degree 2) -> Neighbor degrees: [2, 2]
# Node Makuta (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimogōri (degree 2) -> Neighbor degrees: [2, 2]
# Node Obitsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Tawarada (degree 2) -> Neighbor degrees: [2, 2]
# Node Kururi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hirayama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Matsuoka (degree 2) -> Neighbor degrees: [2, 1]
# Node Kazusa-Kameyama (degree 1) -> Neighbor degrees: [2]
# Node Maegata (degree 2) -> Neighbor degrees: [3, 2]
# Node Ōkama (degree 2) -> Neighbor degrees: [2, 2]
# Node Koiwai (degree 2) -> Neighbor degrees: [2, 2]
# Node Shizukuishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Harukiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Akabuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Tazawako (degree 2) -> Neighbor degrees: [2, 2]
# Node Sashimaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Jindai (degree 2) -> Neighbor degrees: [2, 2]
# Node Shōden (degree 2) -> Neighbor degrees: [2, 2]
# Node Kakunodate (degree 2) -> Neighbor degrees: [2, 2]
# Node Uguisuno (degree 2) -> Neighbor degrees: [2, 2]
# Node Ugo-Nagano (degree 2) -> Neighbor degrees: [2, 2]
# Node Yariminai (degree 2) -> Neighbor degrees: [2, 2]
# Node Ugo-Yotsuya (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Ōmagari (degree 2) -> Neighbor degrees: [2, 1]
# Node Ōmagari (degree 1) -> Neighbor degrees: [2]
# Node Ōme (degree 1) -> Neighbor degrees: [2]
# Node Miyanohira (degree 2) -> Neighbor degrees: [1, 2]
# Node Hinatawada (degree 2) -> Neighbor degrees: [2, 2]
# Node Ishigamimae (degree 2) -> Neighbor degrees: [2, 2]
# Node Futamatao (degree 2) -> Neighbor degrees: [2, 2]
# Node Ikusabata (degree 2) -> Neighbor degrees: [2, 1]
# Node Sawai (degree 1) -> Neighbor degrees: [2]
# Node Kori (degree 1) -> Neighbor degrees: [2]
# Node Hatonosu (degree 2) -> Neighbor degrees: [1, 2]
# Node Shiromaru (degree 2) -> Neighbor degrees: [2, 1]
# Node Oku-Tama (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Kashiwazaki (degree 2) -> Neighbor degrees: [3, 2]
# Node Nishi-Nakadōri (degree 2) -> Neighbor degrees: [2, 2]
# Node Arahama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kariwa (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishiyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Raihai (degree 2) -> Neighbor degrees: [2, 2]
# Node Ishiji (degree 2) -> Neighbor degrees: [2, 2]
# Node Oginojō (degree 2) -> Neighbor degrees: [2, 1]
# Node Izumozaki (degree 1) -> Neighbor degrees: [2]
# Node Ojimaya (degree 1) -> Neighbor degrees: [2]
# Node Kirihara (degree 2) -> Neighbor degrees: [1, 2]
# Node Teradomari (degree 2) -> Neighbor degrees: [2, 2]
# Node Bunsui (degree 2) -> Neighbor degrees: [2, 2]
# Node Aōzu (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Yoshida (degree 2) -> Neighbor degrees: [4, 2]
# Node Kita-Yoshida (degree 2) -> Neighbor degrees: [4, 1]
# Node Iwamuro (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Sone (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Akatsuka (degree 2) -> Neighbor degrees: [1, 2]
# Node Uchinonishigaoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Uchino (degree 2) -> Neighbor degrees: [2, 2]
# Node Niigata University (degree 2) -> Neighbor degrees: [2, 2]
# Node Terao (degree 2) -> Neighbor degrees: [2, 2]
# Node Kobari (degree 2) -> Neighbor degrees: [2, 3]
# Node Aoyama (degree 3) -> Neighbor degrees: [3, 2, 2]
# Node Kuzumi (degree 2) -> Neighbor degrees: [4, 2]
# Node Namegawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimōsa-Kōzaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōto (degree 2) -> Neighbor degrees: [2, 2]
# Node Suigō (degree 2) -> Neighbor degrees: [3, 2]
# Node Omigawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Sasagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimōsa-Tachibana (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimōsa-Toyosato (degree 2) -> Neighbor degrees: [2, 2]
# Node Shiishiba (degree 2) -> Neighbor degrees: [3, 2]
# Node Tsuruta (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanuma (degree 2) -> Neighbor degrees: [2, 2]
# Node Fubasami (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimotsuke-Ōsawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Imaichi (degree 2) -> Neighbor degrees: [2, 1]
# Node Nikkō (degree 1) -> Neighbor degrees: [2]
# Node Kamatori (degree 2) -> Neighbor degrees: [3, 2]
# Node Honda (degree 2) -> Neighbor degrees: [2, 2]
# Node Toke (degree 2) -> Neighbor degrees: [2, 2]
# Node Honnō (degree 1) -> Neighbor degrees: [2]
# Node Shim-Mobara (degree 2) -> Neighbor degrees: [1, 2]
# Node Mobara (degree 2) -> Neighbor degrees: [2, 2]
# Node Yatsumi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Ichinomiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Torami (degree 2) -> Neighbor degrees: [2, 2]
# Node Taitō (degree 2) -> Neighbor degrees: [2, 2]
# Node Chōjamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Mikado (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōhara (degree 2) -> Neighbor degrees: [2, 2]
# Node Namihana (degree 2) -> Neighbor degrees: [2, 2]
# Node Onjuku (degree 2) -> Neighbor degrees: [2, 2]
# Node Katsuura (degree 2) -> Neighbor degrees: [2, 2]
# Node Ubara (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Okitsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Namegawa-Island (degree 2) -> Neighbor degrees: [2, 2]
# Node Awa-Kominato (degree 2) -> Neighbor degrees: [2, 2]
# Node Awa-Amatsu (degree 2) -> Neighbor degrees: [1, 2]
# Node Akita (degree 1) -> Neighbor degrees: [2]
# Node Izumi-Sotoasahikawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Tsuchizaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Iijima (degree 2) -> Neighbor degrees: [2, 2]
# Node Oiwake (degree 2) -> Neighbor degrees: [2, 2]
# Node Detohama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Futada (degree 2) -> Neighbor degrees: [2, 2]
# Node Futada (degree 2) -> Neighbor degrees: [2, 2]
# Node Tennō (degree 2) -> Neighbor degrees: [2, 2]
# Node Funakoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakimoto (degree 2) -> Neighbor degrees: [2, 2]
# Node Hadachi (degree 2) -> Neighbor degrees: [2, 1]
# Node Oga (degree 1) -> Neighbor degrees: [2]
# Node Yonezawa (degree 1) -> Neighbor degrees: [2]
# Node Minami-Yonezawa (degree 2) -> Neighbor degrees: [1, 1]
# Node Nishi-Yonezawa (degree 1) -> Neighbor degrees: [2]
# Node Chūgun (degree 1) -> Neighbor degrees: [2]
# Node Uzen-Komatsu (degree 2) -> Neighbor degrees: [1, 2]
# Node Inukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Imaizumi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hagyū (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Tsubaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Tenoko (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Numazawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Isaryō (degree 2) -> Neighbor degrees: [2, 1]
# Node Uzem-Matsuoka (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Kanamaru (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Katakai (degree 2) -> Neighbor degrees: [1, 2]
# Node Echigo-Shimoseki (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Ōshima (degree 2) -> Neighbor degrees: [3, 2]
# Node Hachiōji (degree 1) -> Neighbor degrees: [2]
# Node Kita-Hachiōji (degree 2) -> Neighbor degrees: [1, 2]
# Node Komiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Haijima (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Fussa (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakonegasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kaneko (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Hannō (degree 2) -> Neighbor degrees: [2, 2]
# Node Komagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Moro (degree 2) -> Neighbor degrees: [2, 2]
# Node Ogose (degree 2) -> Neighbor degrees: [2, 2]
# Node Myōkaku (degree 2) -> Neighbor degrees: [2, 2]
# Node Ogawamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Takezawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Orihara (degree 2) -> Neighbor degrees: [2, 1]
# Node Yorii (degree 1) -> Neighbor degrees: [2]
# Node Matsuhisa (degree 1) -> Neighbor degrees: [2]
# Node Kodama (degree 2) -> Neighbor degrees: [1, 2]
# Node Tanshō (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumma-Fujioka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Fujioka (degree 2) -> Neighbor degrees: [3, 2]
# Node Kuriyagawa (degree 2) -> Neighbor degrees: [3, 2]
# Node Sugō (degree 2) -> Neighbor degrees: [2, 2]
# Node Takizawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Sibutami (degree 2) -> Neighbor degrees: [2, 2]
# Node Kōma (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Ōbuke (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōbuke (degree 2) -> Neighbor degrees: [2, 2]
# Node Tairadate (degree 2) -> Neighbor degrees: [2, 2]
# Node Kitamori (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsuohachimantai (degree 2) -> Neighbor degrees: [2, 2]
# Node Appi-Kōgen (degree 2) -> Neighbor degrees: [2, 2]
# Node Akasakata (degree 2) -> Neighbor degrees: [2, 2]
# Node Koyanohata (degree 2) -> Neighbor degrees: [2, 2]
# Node Arayashimmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokoma (degree 2) -> Neighbor degrees: [2, 2]
# Node Tayama (degree 2) -> Neighbor degrees: [2, 2]
# Node Anihata (degree 2) -> Neighbor degrees: [2, 2]
# Node Yuze-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Hachimantai (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikucyū-Ōsato (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazunohanawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibahira (degree 2) -> Neighbor degrees: [2, 2]
# Node Towadaminami (degree 2) -> Neighbor degrees: [2, 2]
# Node Suehiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Dobukai (degree 2) -> Neighbor degrees: [2, 2]
# Node Sawajiri (degree 2) -> Neighbor degrees: [2, 2]
# Node Jūnisho (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōtaki-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōgita (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Ōdate (degree 2) -> Neighbor degrees: [2, 1]
# Node Ōdate (degree 1) -> Neighbor degrees: [2]
# Node Gumma-Sōja (degree 2) -> Neighbor degrees: [2, 2]
# Node Yagihara (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Ubashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Onogami (degree 2) -> Neighbor degrees: [2, 2]
# Node Onogami-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Ichishiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakanojō (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumma-Haramachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Gōbara (degree 2) -> Neighbor degrees: [2, 2]
# Node Yagura (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawarayu-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Naganoharakusatsuguchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumma-Ōtsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Haneo (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukurogura (degree 2) -> Neighbor degrees: [2, 2]
# Node Manza･kazawaguchi (degree 2) -> Neighbor degrees: [2, 1]
# Node Ōmae (degree 1) -> Neighbor degrees: [2]
# Node Sendai Airport (degree 1) -> Neighbor degrees: [2]
# Node Mitazono (degree 2) -> Neighbor degrees: [1, 2]
# Node Morisekinoshita (degree 2) -> Neighbor degrees: [2, 2]
# Node Natori (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Sendai (degree 2) -> Neighbor degrees: [2, 2]
# Node Taishidō (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Masukata (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Zennami (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuya (degree 2) -> Neighbor degrees: [2, 2]
# Node Furukuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Takaya (degree 2) -> Neighbor degrees: [2, 2]
# Node Kiyokawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Karikawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Minamino (degree 2) -> Neighbor degrees: [3, 2]
# Node Wabuchi (degree 2) -> Neighbor degrees: [3, 2]
# Node Nonodake (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Toyosato (degree 2) -> Neighbor degrees: [2, 2]
# Node Mitakedō (degree 2) -> Neighbor degrees: [2, 1]
# Node Yanaizu (degree 1) -> Neighbor degrees: [2]
# Node Otabayashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yūki (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Yūki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Tamado (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimodate (degree 2) -> Neighbor degrees: [2, 2]
# Node Niihari (degree 2) -> Neighbor degrees: [2, 2]
# Node Yamato (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwase (degree 2) -> Neighbor degrees: [2, 2]
# Node Haguro (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukuhara (degree 2) -> Neighbor degrees: [2, 2]
# Node Inada (degree 2) -> Neighbor degrees: [2, 2]
# Node Kasama (degree 2) -> Neighbor degrees: [2, 2]
# Node Shishido (degree 2) -> Neighbor degrees: [2, 1]
# Node Tomobe (degree 1) -> Neighbor degrees: [2]
# Degree sum: {2: 2630, 3: 83, 1: 201, 0: 0, 4: 16}
# Degree count: {2: 1336, 3: 42, 1: 100, 0: 0, 4: 8}
# k_nn(k): {2: 1.968562874251497, 3: 1.9761904761904763, 1: 2.01, 0: 0, 4: 2.0}

# %%
import networkx as nx
import random
import matplotlib.pyplot as plt

def degree_preserving_randomization(G, num_swaps):
    """
    Perform degree-preserving randomization of an undirected graph, ensuring it remains simple
    and no edge is used more than once during a single swap.

    Parameters:
        G (networkx.Graph): The input graph.
        num_swaps (int): The number of edge swaps to perform.

    Returns:
        G_randomized (networkx.Graph): A new graph with randomized edges.
    """
    # Make a copy of the input graph to avoid modifying the original
    G_randomized = G.copy()
    swaps = 0
    attempts = 0
    max_attempts = num_swaps * 10  # To avoid infinite loops if swaps are not feasible

    while swaps < num_swaps and attempts < max_attempts:
        attempts += 1

        # Dynamically retrieve the edge list to ensure consistency
        edges = list(G_randomized.edges())
        
        # Randomly select two distinct edges (a, b) and (c, d)
        edge1, edge2 = random.sample(edges, 2)
        a, b = edge1
        c, d = edge2

        # Skip if the swap creates self-loops or duplicate edges
        if len({a, b, c, d}) < 4:  # Self-loop check
            continue
        if (a, d) in edges or (c, b) in edges:  # Duplicate edge check
            continue

        # Perform the edge swap
        G_randomized.remove_edge(a, b)
        G_randomized.remove_edge(c, d)
        G_randomized.add_edge(a, d)
        G_randomized.add_edge(c, b)

        swaps += 1

    if attempts >= max_attempts:
        print(f"Stopped after {attempts} attempts with {swaps} successful swaps.")
    else:
        print(f"Completed {swaps} swaps successfully.")

    return G_randomized

# %%
randomized_undir_G = degree_preserving_randomization(undirected_G, 10000)
# Out:
# Completed 10000 swaps successfully.

# %%
knn_randomized = calculate_knn_with_debug(randomized_undir_G)
plot_knn(knn_randomized)
# Out:
# Node degrees: {'Kogota': 2, 'Kami-Wakuya': 2, 'Wakuya': 2, 'Maeyachi': 3, 'Kakeyama': 2, 'Kanomata': 2, 'Sobanokami': 2, 'Ishinomaki': 2, 'Rikuzen-Inai': 2, 'Watanoha': 2, 'Mangokuura': 2, 'Sawada': 2, 'Urashuku': 2, 'Onagawa': 1, 'Sawara': 2, 'Katori': 3, 'Jūnikyō': 2, 'Itako': 2, 'Nobukata': 2, 'Kashimajingū': 2, 'Kashima-Soccer Stadium（Seasonal）': 1, 'Chiba': 2, 'Higashi-Chiba': 2, 'Tsuga': 2, 'Yotsukaidō': 2, 'Monoi': 2, 'Sakura': 3, 'Minami-Shisui': 1, 'Yachimata': 0, 'Narutō': 2, 'Matsuo': 2, 'Yokoshiba': 2, 'Iigura': 2, 'Yōkaichiba': 2, 'Higata': 2, 'Asahi': 2, 'Iioka': 2, 'Kurahashi': 2, 'Saruda': 2, 'Matsugishi': 3, 'Chōshi': 1, 'Chigasaki': 1, 'Kita-Chigasaki': 1, 'Samukawa': 1, 'Miyayama': 2, 'Kurami': 2, 'Kadosawabashi': 2, 'Shake': 2, 'Atsugi': 2, 'Ebina': 2, 'Iriya': 2, 'Sōbudaishita': 2, 'Shimomizo': 2, 'Harataima': 2, 'Banda': 2, 'Kamimizo': 2, 'Minami-Hashimoto': 1, 'Kitaura': 2, 'Rikuzen-Yachi': 2, 'Furukawa': 2, 'Tsukanome': 2, 'Nishi-Furukawa': 2, 'Higashi-Ōsaki': 2, 'Nishi-Ōsaki': 2, 'Iwadeyama': 2, 'Yūbikan': 2, 'Kaminome': 2, 'Ikezuki': 2, 'Kawatabi-Onsen': 2, 'Narukogotenyu': 2, 'Naruko-Onsen': 2, 'Nakayamadaira-Onsen': 2, 'Sakaida': 2, 'Akakura-Onsen': 2, 'Tachikōji': 2, 'Mogami': 2, 'Ōhori': 2, 'Usugi': 2, 'Semi-Onsen': 2, 'Higashi-Nagasawa': 2, 'Nagasawa': 2, 'Minami-Shinjō': 2, 'Shinjō': 2, 'Aomori': 1, 'Aburakawa': 2, 'Tsugaru-Miyata': 2, 'Okunai': 2, 'Hidariseki': 2, 'Ushirogata': 2, 'Nakasawa': 2, 'Yomogita': 2, 'Gōsawa': 2, 'Seheji': 2, 'Kanita': 1, 'Ōdai': 1, 'Tsugaru-Futamata': 2, 'Ōkawadai': 2, 'Imabetsu': 2, 'Tsugaru-Hamana': 2, 'Mimmaya': 1, 'Atami': 1, 'Kinomiya': 2, 'Izu-Taga': 2, 'Ajiro': 2, 'Usami': 2, 'Itō': 1, 'Hama-Kawasaki': 1, 'Odasakae': 2, 'Kawasakishimmachi': 2, 'Hatchōnawate': 2, 'Shitte': 1, 'Hon-Chiba': 2, 'Soga': 3, 'Hamano': 2, 'Yawatajuku': 2, 'Goi': 2, 'Anegasaki': 2, 'Nagaura': 2, 'Sodegaura': 2, 'Iwane': 2, 'Kisarazu': 2, 'Kimitsu': 2, 'Aohori': 2, 'Ōnuki': 2, 'Sanukimachi': 2, 'Kazusa-Minato': 1, 'Hama-Kanaya': 1, 'Hota': 2, 'Awa-Katsuyama': 2, 'Iwai': 2, 'Tomiura': 2, 'Nakofunakata': 2, 'Tateyama': 2, 'Chikura': 0, 'Minamihara': 1, 'Wadaura': 2, 'Emi': 1, 'Awa-Kamogawa': 1, 'Hanamaki': 1, 'Nitanai': 2, 'Shin-Hanamaki': 2, 'Oyamada': 2, 'Tsuchizawa': 2, 'Haruyama': 2, 'Iwanebashi': 2, 'Miyamori': 2, 'Kashiwagidaira': 2, 'Masuzawa': 2, 'Arayamae': 2, 'Iwate-Futsukamachi': 2, 'Ayaori': 2, 'Tōno': 2, 'Aozasa': 2, 'Iwate-Kamigō': 2, 'Hirakura': 2, 'Ashigase': 2, 'Kami-Arisu': 2, 'Rikuchū-Ōhashi': 2, 'Dōsen': 2, 'Matsukura': 2, 'Kosano': 2, 'Kamaishi': 1, 'Shisui': 2, 'Narita': 4, 'Narita Airport Terminal 2・3': 2, 'Narita Airport Terminal 1': 1, 'Jimbohara': 1, 'Shimmachi': 2, 'Kuragano': 3, 'Takasaki': 3, 'Kobuchizawa': 1, 'Kai-Koizumi': 2, 'Kai-Ōizumi': 1, 'Nobeyama': 1, 'Shinano-Kawakami': 2, 'Saku-Hirose': 2, 'Saku-Uminokuchi': 2, 'Umijiri': 2, 'Matsubarako': 2, 'Koumi': 2, 'Managashi': 1, 'Yachiho': 0, 'Haguroshita': 1, 'Aonuma': 2, 'Usuda': 2, 'Tatsuokajō': 2, 'Ōtabe': 2, 'Nakagomi': 2, 'Namezu': 2, 'Kita-Nakagomi': 2, 'Iwamurada': 2, 'Sakudaira': 2, 'Nakasato': 2, 'Misato': 2, 'Mitsuoka': 2, 'Otome': 2, 'Higashi-Komoro': 2, 'Komoro': 1, 'Sendai': 2, 'Tōshōgū': 2, 'Kita-Sendai': 1, 'Tōhoku Fukushi University': 1, 'Kunimi': 2, 'Kuzuoka': 2, 'Rikuzen-Ochiai': 2, 'Ayashi': 2, 'Rikuzen-Shirasawa': 2, 'Kumagane': 2, 'Sakunami': 2, 'Oku-Nikkawa': 2, 'Omoshiroyama-Kōgen': 2, 'Yamadera': 1, 'Uzen-Chitose': 2, 'Kita-Yamagata': 3, 'Yamagata': 1, 'Aizu-Wakamatsu': 1, 'Nanukamachi': 2, 'Nishi-Wakamatsu': 2, 'Aizu-Hongō': 2, 'Aizu-Takada': 2, 'Negishi': 2, 'Niitsuru': 2, 'Wakamiya': 2, 'Aizu-Bange': 2, 'Tōdera': 2, 'Aizu-Sakamoto': 2, 'Aizu-Yanaizu': 2, 'Gōdo': 2, 'Takiya': 2, 'Aizu-Hinohara': 2, 'Aizu-Nishikata': 2, 'Aizu-Miyashita': 1, 'Aizu-Mizunuma': 1, 'Aizu-Nakagawa': 2, 'Aizu-Kawaguchi': 2, 'Honna': 2, 'Aizu-Kosugawa': 2, 'Aizu-Yokota': 2, 'Aizu-Ōshio': 2, 'Aizu-Shiozawa': 2, 'Aizu-Gamō': 2, 'Tadami': 2, 'Ōshirakawa': 2, 'Irihirose': 2, 'Kamijō': 2, 'Echigo-Suhara': 2, 'Uon ...
# Node Kogota (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Wakuya (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakuya (degree 2) -> Neighbor degrees: [2, 1]
# Node Maeyachi (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Kakeyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanomata (degree 2) -> Neighbor degrees: [2, 2]
# Node Sobanokami (degree 2) -> Neighbor degrees: [2, 2]
# Node Ishinomaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Inai (degree 2) -> Neighbor degrees: [2, 2]
# Node Watanoha (degree 2) -> Neighbor degrees: [2, 2]
# Node Mangokuura (degree 2) -> Neighbor degrees: [2, 2]
# Node Sawada (degree 2) -> Neighbor degrees: [2, 2]
# Node Urashuku (degree 2) -> Neighbor degrees: [3, 2]
# Node Onagawa (degree 1) -> Neighbor degrees: [2]
# Node Sawara (degree 2) -> Neighbor degrees: [2, 2]
# Node Katori (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Jūnikyō (degree 2) -> Neighbor degrees: [2, 2]
# Node Itako (degree 2) -> Neighbor degrees: [2, 1]
# Node Nobukata (degree 2) -> Neighbor degrees: [2, 2]
# Node Kashimajingū (degree 2) -> Neighbor degrees: [2, 2]
# Node Kashima-Soccer Stadium（Seasonal） (degree 1) -> Neighbor degrees: [2]
# Node Chiba (degree 2) -> Neighbor degrees: [2, 3]
# Node Higashi-Chiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuga (degree 2) -> Neighbor degrees: [2, 2]
# Node Yotsukaidō (degree 2) -> Neighbor degrees: [2, 2]
# Node Monoi (degree 2) -> Neighbor degrees: [2, 2]
# Node Sakura (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Minami-Shisui (degree 1) -> Neighbor degrees: [2]
# Node Yachimata (degree 0) -> Neighbor degrees: []
# Node Narutō (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsuo (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokoshiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Iigura (degree 2) -> Neighbor degrees: [2, 2]
# Node Yōkaichiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Higata (degree 2) -> Neighbor degrees: [2, 2]
# Node Asahi (degree 2) -> Neighbor degrees: [2, 2]
# Node Iioka (degree 2) -> Neighbor degrees: [2, 1]
# Node Kurahashi (degree 2) -> Neighbor degrees: [1, 2]
# Node Saruda (degree 2) -> Neighbor degrees: [2, 4]
# Node Matsugishi (degree 3) -> Neighbor degrees: [2, 1, 2]
# Node Chōshi (degree 1) -> Neighbor degrees: [2]
# Node Chigasaki (degree 1) -> Neighbor degrees: [2]
# Node Kita-Chigasaki (degree 1) -> Neighbor degrees: [2]
# Node Samukawa (degree 1) -> Neighbor degrees: [2]
# Node Miyayama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kurami (degree 2) -> Neighbor degrees: [2, 2]
# Node Kadosawabashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shake (degree 2) -> Neighbor degrees: [2, 3]
# Node Atsugi (degree 2) -> Neighbor degrees: [2, 2]
# Node Ebina (degree 2) -> Neighbor degrees: [2, 2]
# Node Iriya (degree 2) -> Neighbor degrees: [1, 2]
# Node Sōbudaishita (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimomizo (degree 2) -> Neighbor degrees: [2, 2]
# Node Harataima (degree 2) -> Neighbor degrees: [1, 2]
# Node Banda (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamimizo (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Hashimoto (degree 1) -> Neighbor degrees: [2]
# Node Kitaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Yachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Furukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsukanome (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Furukawa (degree 2) -> Neighbor degrees: [2, 3]
# Node Higashi-Ōsaki (degree 2) -> Neighbor degrees: [1, 2]
# Node Nishi-Ōsaki (degree 2) -> Neighbor degrees: [2, 1]
# Node Iwadeyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Yūbikan (degree 2) -> Neighbor degrees: [2, 2]
# Node Kaminome (degree 2) -> Neighbor degrees: [2, 2]
# Node Ikezuki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawatabi-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Narukogotenyu (degree 2) -> Neighbor degrees: [2, 2]
# Node Naruko-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakayamadaira-Onsen (degree 2) -> Neighbor degrees: [2, 1]
# Node Sakaida (degree 2) -> Neighbor degrees: [2, 2]
# Node Akakura-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Tachikōji (degree 2) -> Neighbor degrees: [2, 2]
# Node Mogami (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōhori (degree 2) -> Neighbor degrees: [2, 2]
# Node Usugi (degree 2) -> Neighbor degrees: [2, 2]
# Node Semi-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Nagasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Shinjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Aomori (degree 1) -> Neighbor degrees: [2]
# Node Aburakawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsugaru-Miyata (degree 2) -> Neighbor degrees: [2, 2]
# Node Okunai (degree 2) -> Neighbor degrees: [2, 2]
# Node Hidariseki (degree 2) -> Neighbor degrees: [2, 2]
# Node Ushirogata (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Yomogita (degree 2) -> Neighbor degrees: [2, 2]
# Node Gōsawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Seheji (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanita (degree 1) -> Neighbor degrees: [2]
# Node Ōdai (degree 1) -> Neighbor degrees: [1]
# Node Tsugaru-Futamata (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōkawadai (degree 2) -> Neighbor degrees: [2, 1]
# Node Imabetsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsugaru-Hamana (degree 2) -> Neighbor degrees: [2, 2]
# Node Mimmaya (degree 1) -> Neighbor degrees: [2]
# Node Atami (degree 1) -> Neighbor degrees: [4]
# Node Kinomiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Izu-Taga (degree 2) -> Neighbor degrees: [2, 2]
# Node Ajiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Usami (degree 2) -> Neighbor degrees: [2, 2]
# Node Itō (degree 1) -> Neighbor degrees: [2]
# Node Hama-Kawasaki (degree 1) -> Neighbor degrees: [2]
# Node Odasakae (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawasakishimmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hatchōnawate (degree 2) -> Neighbor degrees: [2, 2]
# Node Shitte (degree 1) -> Neighbor degrees: [2]
# Node Hon-Chiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Soga (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Hamano (degree 2) -> Neighbor degrees: [2, 1]
# Node Yawatajuku (degree 2) -> Neighbor degrees: [2, 2]
# Node Goi (degree 2) -> Neighbor degrees: [2, 2]
# Node Anegasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Sodegaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwane (degree 2) -> Neighbor degrees: [2, 1]
# Node Kisarazu (degree 2) -> Neighbor degrees: [2, 2]
# Node Kimitsu (degree 2) -> Neighbor degrees: [2, 3]
# Node Aohori (degree 2) -> Neighbor degrees: [3, 2]
# Node Ōnuki (degree 2) -> Neighbor degrees: [2, 2]
# Node Sanukimachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Minato (degree 1) -> Neighbor degrees: [2]
# Node Hama-Kanaya (degree 1) -> Neighbor degrees: [2]
# Node Hota (degree 2) -> Neighbor degrees: [2, 2]
# Node Awa-Katsuyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwai (degree 2) -> Neighbor degrees: [2, 2]
# Node Tomiura (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakofunakata (degree 2) -> Neighbor degrees: [2, 2]
# Node Tateyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Chikura (degree 0) -> Neighbor degrees: []
# Node Minamihara (degree 1) -> Neighbor degrees: [2]
# Node Wadaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Emi (degree 1) -> Neighbor degrees: [2]
# Node Awa-Kamogawa (degree 1) -> Neighbor degrees: [2]
# Node Hanamaki (degree 1) -> Neighbor degrees: [2]
# Node Nitanai (degree 2) -> Neighbor degrees: [2, 2]
# Node Shin-Hanamaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Oyamada (degree 2) -> Neighbor degrees: [2, 1]
# Node Tsuchizawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Haruyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwanebashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Miyamori (degree 2) -> Neighbor degrees: [2, 2]
# Node Kashiwagidaira (degree 2) -> Neighbor degrees: [2, 2]
# Node Masuzawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Arayamae (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwate-Futsukamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Ayaori (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōno (degree 2) -> Neighbor degrees: [2, 2]
# Node Aozasa (degree 2) -> Neighbor degrees: [3, 2]
# Node Iwate-Kamigō (degree 2) -> Neighbor degrees: [2, 2]
# Node Hirakura (degree 2) -> Neighbor degrees: [2, 2]
# Node Ashigase (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Arisu (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Ōhashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Dōsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsukura (degree 2) -> Neighbor degrees: [2, 2]
# Node Kosano (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamaishi (degree 1) -> Neighbor degrees: [2]
# Node Shisui (degree 2) -> Neighbor degrees: [2, 2]
# Node Narita (degree 4) -> Neighbor degrees: [2, 2, 2, 2]
# Node Narita Airport Terminal 2・3 (degree 2) -> Neighbor degrees: [2, 2]
# Node Narita Airport Terminal 1 (degree 1) -> Neighbor degrees: [2]
# Node Jimbohara (degree 1) -> Neighbor degrees: [2]
# Node Shimmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuragano (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Takasaki (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Kobuchizawa (degree 1) -> Neighbor degrees: [2]
# Node Kai-Koizumi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kai-Ōizumi (degree 1) -> Neighbor degrees: [2]
# Node Nobeyama (degree 1) -> Neighbor degrees: [2]
# Node Shinano-Kawakami (degree 2) -> Neighbor degrees: [2, 2]
# Node Saku-Hirose (degree 2) -> Neighbor degrees: [2, 2]
# Node Saku-Uminokuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Umijiri (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsubarako (degree 2) -> Neighbor degrees: [2, 2]
# Node Koumi (degree 2) -> Neighbor degrees: [2, 2]
# Node Managashi (degree 1) -> Neighbor degrees: [1]
# Node Yachiho (degree 0) -> Neighbor degrees: []
# Node Haguroshita (degree 1) -> Neighbor degrees: [2]
# Node Aonuma (degree 2) -> Neighbor degrees: [3, 2]
# Node Usuda (degree 2) -> Neighbor degrees: [2, 2]
# Node Tatsuokajō (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōtabe (degree 2) -> Neighbor degrees: [1, 2]
# Node Nakagomi (degree 2) -> Neighbor degrees: [2, 1]
# Node Namezu (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Nakagomi (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwamurada (degree 2) -> Neighbor degrees: [2, 2]
# Node Sakudaira (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakasato (degree 2) -> Neighbor degrees: [2, 2]
# Node Misato (degree 2) -> Neighbor degrees: [2, 2]
# Node Mitsuoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Otome (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Komoro (degree 2) -> Neighbor degrees: [2, 2]
# Node Komoro (degree 1) -> Neighbor degrees: [2]
# Node Sendai (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōshōgū (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Sendai (degree 1) -> Neighbor degrees: [1]
# Node Tōhoku Fukushi University (degree 1) -> Neighbor degrees: [2]
# Node Kunimi (degree 2) -> Neighbor degrees: [1, 2]
# Node Kuzuoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Ochiai (degree 2) -> Neighbor degrees: [2, 2]
# Node Ayashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuzen-Shirasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kumagane (degree 2) -> Neighbor degrees: [2, 3]
# Node Sakunami (degree 2) -> Neighbor degrees: [2, 2]
# Node Oku-Nikkawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Omoshiroyama-Kōgen (degree 2) -> Neighbor degrees: [2, 2]
# Node Yamadera (degree 1) -> Neighbor degrees: [2]
# Node Uzen-Chitose (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Yamagata (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Yamagata (degree 1) -> Neighbor degrees: [2]
# Node Aizu-Wakamatsu (degree 1) -> Neighbor degrees: [2]
# Node Nanukamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Wakamatsu (degree 2) -> Neighbor degrees: [2, 3]
# Node Aizu-Hongō (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Takada (degree 2) -> Neighbor degrees: [2, 2]
# Node Negishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Niitsuru (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakamiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Bange (degree 2) -> Neighbor degrees: [2, 1]
# Node Tōdera (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Sakamoto (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Yanaizu (degree 2) -> Neighbor degrees: [2, 2]
# Node Gōdo (degree 2) -> Neighbor degrees: [1, 1]
# Node Takiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Hinohara (degree 2) -> Neighbor degrees: [1, 2]
# Node Aizu-Nishikata (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Miyashita (degree 1) -> Neighbor degrees: [2]
# Node Aizu-Mizunuma (degree 1) -> Neighbor degrees: [2]
# Node Aizu-Nakagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Kawaguchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Honna (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Kosugawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Yokota (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Ōshio (degree 2) -> Neighbor degrees: [2, 2]
# Node Aizu-Shiozawa (degree 2) -> Neighbor degrees: [4, 2]
# Node Aizu-Gamō (degree 2) -> Neighbor degrees: [2, 2]
# Node Tadami (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōshirakawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Irihirose (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamijō (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Suhara (degree 2) -> Neighbor degrees: [1, 2]
# Node Uonuma-Tanaka (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Hirose (degree 2) -> Neighbor degrees: [2, 2]
# Node Yabukami (degree 2) -> Neighbor degrees: [3, 2]
# Node Koide (degree 1) -> Neighbor degrees: [2]
# Node Ōami (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukutawara (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōgane (degree 2) -> Neighbor degrees: [2, 1]
# Node Gumyō (degree 2) -> Neighbor degrees: [2, 2]
# Node Takasakitonyamachi (degree 1) -> Neighbor degrees: [2]
# Node Shim-Maebashi (degree 2) -> Neighbor degrees: [1, 2]
# Node Maebashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Maebashiōshima (degree 2) -> Neighbor degrees: [2, 2]
# Node Komagata (degree 2) -> Neighbor degrees: [2, 2]
# Node Isesaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kunisada (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwajuku (degree 2) -> Neighbor degrees: [1, 2]
# Node Kiryū (degree 2) -> Neighbor degrees: [2, 2]
# Node Omata (degree 2) -> Neighbor degrees: [2, 2]
# Node Yamamae (degree 2) -> Neighbor degrees: [2, 2]
# Node Ashikaga (degree 2) -> Neighbor degrees: [3, 2]
# Node Ashikaga Flower Park (degree 2) -> Neighbor degrees: [2, 2]
# Node Tomita (degree 2) -> Neighbor degrees: [2, 2]
# Node Sano (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwafune (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōhirashita (degree 2) -> Neighbor degrees: [2, 2]
# Node Tochigi (degree 2) -> Neighbor degrees: [2, 2]
# Node Omoigawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Oyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Hachinohe (degree 1) -> Neighbor degrees: [2]
# Node Naganawashiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Hon-Hachinohe (degree 2) -> Neighbor degrees: [2, 2]
# Node Konakano (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Minato (degree 1) -> Neighbor degrees: [2]
# Node Same (degree 1) -> Neighbor degrees: [1]
# Node Mutsu-Shirahama (degree 2) -> Neighbor degrees: [2, 2]
# Node Tanesashikaigan (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōkuki (degree 2) -> Neighbor degrees: [2, 1]
# Node Kanehama (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōja (degree 2) -> Neighbor degrees: [2, 1]
# Node Hashikami (degree 2) -> Neighbor degrees: [2, 2]
# Node Kadonohama (degree 2) -> Neighbor degrees: [2, 2]
# Node Hiranai (degree 2) -> Neighbor degrees: [2, 2]
# Node Taneichi (degree 2) -> Neighbor degrees: [2, 2]
# Node Tamagawa (degree 2) -> Neighbor degrees: [2, 1]
# Node Shukunohe (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Yagi (degree 2) -> Neighbor degrees: [2, 1]
# Node Uge (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Nakano (degree 2) -> Neighbor degrees: [2, 2]
# Node Samuraihama (degree 2) -> Neighbor degrees: [1, 2]
# Node Rikuchū-Natsui (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuji (degree 1) -> Neighbor degrees: [2]
# Node Abiko (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Abiko (degree 2) -> Neighbor degrees: [2, 2]
# Node Kohoku (degree 1) -> Neighbor degrees: [2]
# Node Fusa (degree 1) -> Neighbor degrees: [1]
# Node Kioroshi (degree 1) -> Neighbor degrees: [2]
# Node Ajiki (degree 1) -> Neighbor degrees: [2]
# Node Shimōsa-Manzaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Morioka (degree 3) -> Neighbor degrees: [3, 2, 2]
# Node Kami-Morioka (degree 2) -> Neighbor degrees: [2, 2]
# Node Yamagishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Yonai (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuzakai (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsukusa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawauchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakoishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Rikuchū-Kawai (degree 2) -> Neighbor degrees: [2, 2]
# Node Haratai (degree 2) -> Neighbor degrees: [2, 2]
# Node Moichi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hikime (degree 2) -> Neighbor degrees: [2, 2]
# Node Kebaraichi (degree 2) -> Neighbor degrees: [2, 2]
# Node Sentoku (degree 2) -> Neighbor degrees: [2, 2]
# Node Miyako (degree 1) -> Neighbor degrees: [2]
# Node Kitakami (degree 0) -> Neighbor degrees: []
# Node Ezuriko (degree 1) -> Neighbor degrees: [2]
# Node Fujine (degree 2) -> Neighbor degrees: [2, 2]
# Node Tatekawame (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokokawame (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakasennin (degree 2) -> Neighbor degrees: [2, 2]
# Node Yudakinshūko (degree 2) -> Neighbor degrees: [2, 2]
# Node Hotto-Yuda (degree 2) -> Neighbor degrees: [1, 2]
# Node Yuda-Kōgen (degree 2) -> Neighbor degrees: [2, 2]
# Node Kurosawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Komatsukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Ainono (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokote (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Noshiro (degree 1) -> Neighbor degrees: [2]
# Node Noshiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Mukai-Noshiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Noshiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Torigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Sawame (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Hachimori (degree 2) -> Neighbor degrees: [2, 2]
# Node Hachimori (degree 2) -> Neighbor degrees: [2, 2]
# Node Takinoma (degree 2) -> Neighbor degrees: [2, 2]
# Node Akitashirakami (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwadate (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōmagoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shirakamidaketozanguchi (degree 2) -> Neighbor degrees: [1, 2]
# Node Matsukami (degree 2) -> Neighbor degrees: [2, 2]
# Node Jūniko (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Iwasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Sawabe (degree 2) -> Neighbor degrees: [2, 2]
# Node WeSPa Tsubakiyama (degree 2) -> Neighbor degrees: [2, 3]
# Node Henashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokoiso (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukaura (degree 2) -> Neighbor degrees: [2, 2]
# Node Hiroto (degree 2) -> Neighbor degrees: [1, 2]
# Node Oirase (degree 2) -> Neighbor degrees: [2, 2]
# Node Todoroki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kasose (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōdose (degree 2) -> Neighbor degrees: [2, 2]
# Node Senjōjiki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Kanegasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Yanagita (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Akaishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Ajigasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Narusawa (degree 1) -> Neighbor degrees: [2]
# Node Mutsu-Morita (degree 1) -> Neighbor degrees: [2]
# Node Nakata (degree 2) -> Neighbor degrees: [2, 2]
# Node Kizukuri (degree 2) -> Neighbor degrees: [2, 2]
# Node Goshogawara (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Tsuruda (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsurudomari (degree 2) -> Neighbor degrees: [2, 2]
# Node Itayanagi (degree 1) -> Neighbor degrees: [2]
# Node Fujisaki (degree 1) -> Neighbor degrees: [2]
# Node Kawabe (degree 2) -> Neighbor degrees: [2, 2]
# Node Naijoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hirosaki (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Kanai (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Yamabe (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Kanezawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Nagasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Sagae (degree 2) -> Neighbor degrees: [2, 2]
# Node Sagae (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Sagae (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Takamatsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibahashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Aterazawa (degree 1) -> Neighbor degrees: [2]
# Node Iwaki (degree 1) -> Neighbor degrees: [2]
# Node Akai (degree 2) -> Neighbor degrees: [2, 2]
# Node Ogawagō (degree 2) -> Neighbor degrees: [2, 1]
# Node Eda (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawamae (degree 2) -> Neighbor degrees: [2, 2]
# Node Natsui (degree 2) -> Neighbor degrees: [2, 2]
# Node Ononiimachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Kammata (degree 2) -> Neighbor degrees: [2, 2]
# Node Sugaya (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōgoe (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwaki-Tokiwa (degree 2) -> Neighbor degrees: [2, 1]
# Node Funehiki (degree 2) -> Neighbor degrees: [1, 2]
# Node Kanameta (degree 2) -> Neighbor degrees: [2, 3]
# Node Miharu (degree 2) -> Neighbor degrees: [2, 2]
# Node Mōgi (degree 2) -> Neighbor degrees: [2, 1]
# Node Kōriyama (degree 1) -> Neighbor degrees: [2]
# Node Matsumoto (degree 1) -> Neighbor degrees: [2]
# Node Kita-Matsumoto (degree 2) -> Neighbor degrees: [2, 3]
# Node Shimauchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimatakamatsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Azusabashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hitoichiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Nakagaya (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Toyoshina (degree 2) -> Neighbor degrees: [2, 2]
# Node Toyoshina (degree 2) -> Neighbor degrees: [4, 2]
# Node Hakuyacho (degree 2) -> Neighbor degrees: [2, 2]
# Node Hotaka (degree 2) -> Neighbor degrees: [2, 1]
# Node Ariake (degree 2) -> Neighbor degrees: [2, 2]
# Node Azumi-Oiwake (degree 2) -> Neighbor degrees: [2, 2]
# Node Hosono (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Hosono (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Matsukawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Azumi-Kutsukake (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Tokiwa (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Ōmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Ōmachi (degree 2) -> Neighbor degrees: [2, 1]
# Node Kita-Ōmachi (degree 2) -> Neighbor degrees: [2, 1]
# Node Shinano-Kizaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Inao (degree 2) -> Neighbor degrees: [2, 2]
# Node Uminokuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yanaba (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Kamishiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamishiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Iimori (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakuba (degree 2) -> Neighbor degrees: [2, 2]
# Node Shinano-Moriue (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakubaōike (degree 2) -> Neighbor degrees: [2, 2]
# Node Chikuni (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Otari (degree 1) -> Neighbor degrees: [3]
# Node Utsunomiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Okamoto (degree 2) -> Neighbor degrees: [2, 1]
# Node Hōshakuji (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimotsuke-Hanaoka (degree 2) -> Neighbor degrees: [1, 2]
# Node Niita (degree 2) -> Neighbor degrees: [2, 2]
# Node Kōnoyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōgane (degree 2) -> Neighbor degrees: [2, 2]
# Node Kobana (degree 1) -> Neighbor degrees: [2]
# Node Karasuyama (degree 0) -> Neighbor degrees: []
# Node Yahiko (degree 1) -> Neighbor degrees: [2]
# Node Yahagi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yoshida (degree 4) -> Neighbor degrees: [2, 3, 1, 2]
# Node Nishi-Tsubame (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsubame (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsubamesanjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Sanjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Sanjō (degree 3) -> Neighbor degrees: [2, 2, 3]
# Node Kita-Takasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumma-Yawata (degree 2) -> Neighbor degrees: [2, 2]
# Node Annaka (degree 2) -> Neighbor degrees: [2, 2]
# Node Isobe (degree 2) -> Neighbor degrees: [2, 3]
# Node Matsuida (degree 2) -> Neighbor degrees: [3, 2]
# Node Nishi-Matsuida (degree 2) -> Neighbor degrees: [2, 1]
# Node Yokokawa (degree 1) -> Neighbor degrees: [2]
# Node Niigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Niigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōgata (degree 2) -> Neighbor degrees: [2, 2]
# Node Niizaki (degree 2) -> Neighbor degrees: [3, 1]
# Node Hayadōri (degree 2) -> Neighbor degrees: [1, 3]
# Node Toyosaka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuroyama (degree 2) -> Neighbor degrees: [2, 1]
# Node Sasaki (degree 2) -> Neighbor degrees: [1, 2]
# Node Nishi-Shibata (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibata (degree 2) -> Neighbor degrees: [2, 2]
# Node Kaji (degree 2) -> Neighbor degrees: [1, 2]
# Node Kanazuka (degree 2) -> Neighbor degrees: [3, 2]
# Node Nakajō (degree 2) -> Neighbor degrees: [2, 2]
# Node Hirakida (degree 2) -> Neighbor degrees: [2, 2]
# Node Sakamachi (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Hirabayashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwafunemachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Murakami (degree 2) -> Neighbor degrees: [2, 2]
# Node Majima (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Hayakawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuwagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Imagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Kangawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Gatsugi (degree 2) -> Neighbor degrees: [2, 2]
# Node Fuya (degree 2) -> Neighbor degrees: [2, 2]
# Node Nezugaseki (degree 2) -> Neighbor degrees: [2, 2]
# Node Koiwagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Atsumi-Onsen (degree 2) -> Neighbor degrees: [1, 3]
# Node Iragawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kobato (degree 2) -> Neighbor degrees: [2, 1]
# Node Sanze (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Mizusawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Ōyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuruoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Fujishima (degree 2) -> Neighbor degrees: [2, 3]
# Node Nishibukuro (degree 2) -> Neighbor degrees: [2, 2]
# Node Amarume (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Kita-Amarume (degree 2) -> Neighbor degrees: [1, 1]
# Node Sagoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Sakata (degree 2) -> Neighbor degrees: [3, 2]
# Node Sakata (degree 1) -> Neighbor degrees: [2]
# Node Noheji (degree 1) -> Neighbor degrees: [2]
# Node Kita-Noheji (degree 2) -> Neighbor degrees: [2, 2]
# Node Arito (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukkoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Mutsu-Yokohama (degree 2) -> Neighbor degrees: [1, 2]
# Node Arihata (degree 2) -> Neighbor degrees: [2, 2]
# Node Chikagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanayasawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Akagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimokita (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōminato (degree 1) -> Neighbor degrees: [2]
# Node Naoetsu (degree 1) -> Neighbor degrees: [2]
# Node Kuroi (degree 2) -> Neighbor degrees: [1, 2]
# Node Saigata (degree 2) -> Neighbor degrees: [2, 2]
# Node Dosokohama (degree 2) -> Neighbor degrees: [2, 2]
# Node Katamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Jōgehama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kakizaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Yoneyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kasashima (degree 2) -> Neighbor degrees: [1, 2]
# Node Ōmigawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kujiranami (degree 2) -> Neighbor degrees: [2, 2]
# Node Kashiwazaki (degree 3) -> Neighbor degrees: [2, 2, 4]
# Node Ibarame (degree 1) -> Neighbor degrees: [2]
# Node Kitajō (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Hirota (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagatori (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsukayama (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Iwatsuka (degree 2) -> Neighbor degrees: [2, 2]
# Node Raikōji (degree 2) -> Neighbor degrees: [2, 2]
# Node Maekawa (degree 2) -> Neighbor degrees: [3, 1]
# Node Miyauchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagaoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Nagaoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Oshikiri (degree 2) -> Neighbor degrees: [1, 2]
# Node Mitsuke (degree 2) -> Neighbor degrees: [1, 2]
# Node Obiori (degree 2) -> Neighbor degrees: [2, 2]
# Node Tōkōji (degree 2) -> Neighbor degrees: [2, 2]
# Node Sanjō (degree 2) -> Neighbor degrees: [2, 2]
# Node Honai (degree 2) -> Neighbor degrees: [2, 2]
# Node Kamo (degree 2) -> Neighbor degrees: [2, 2]
# Node Hanyūda (degree 2) -> Neighbor degrees: [2, 2]
# Node Tagami (degree 2) -> Neighbor degrees: [2, 2]
# Node Yashiroda (degree 2) -> Neighbor degrees: [2, 2]
# Node Furutsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Niitsu (degree 2) -> Neighbor degrees: [2, 1]
# Node Satsukino (degree 2) -> Neighbor degrees: [2, 2]
# Node Ogikawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kameda (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Ishiyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Kiyokawa (degree 1) -> Neighbor degrees: [1]
# Node Higashi-Kiyokawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokota (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Yokota (degree 2) -> Neighbor degrees: [2, 1]
# Node Makuta (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimogōri (degree 2) -> Neighbor degrees: [2, 3]
# Node Obitsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Tawarada (degree 2) -> Neighbor degrees: [2, 2]
# Node Kururi (degree 2) -> Neighbor degrees: [1, 2]
# Node Hirayama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Matsuoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Kameyama (degree 1) -> Neighbor degrees: [2]
# Node Maegata (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōkama (degree 2) -> Neighbor degrees: [2, 2]
# Node Koiwai (degree 2) -> Neighbor degrees: [2, 2]
# Node Shizukuishi (degree 2) -> Neighbor degrees: [2, 2]
# Node Harukiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Akabuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Tazawako (degree 2) -> Neighbor degrees: [2, 2]
# Node Sashimaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Jindai (degree 2) -> Neighbor degrees: [2, 2]
# Node Shōden (degree 2) -> Neighbor degrees: [2, 2]
# Node Kakunodate (degree 2) -> Neighbor degrees: [1, 2]
# Node Uguisuno (degree 2) -> Neighbor degrees: [2, 2]
# Node Ugo-Nagano (degree 2) -> Neighbor degrees: [1, 2]
# Node Yariminai (degree 2) -> Neighbor degrees: [2, 2]
# Node Ugo-Yotsuya (degree 2) -> Neighbor degrees: [1, 2]
# Node Kita-Ōmagari (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōmagari (degree 1) -> Neighbor degrees: [2]
# Node Ōme (degree 1) -> Neighbor degrees: [1]
# Node Miyanohira (degree 2) -> Neighbor degrees: [2, 2]
# Node Hinatawada (degree 2) -> Neighbor degrees: [2, 2]
# Node Ishigamimae (degree 2) -> Neighbor degrees: [2, 2]
# Node Futamatao (degree 2) -> Neighbor degrees: [2, 1]
# Node Ikusabata (degree 2) -> Neighbor degrees: [2, 2]
# Node Sawai (degree 1) -> Neighbor degrees: [2]
# Node Kori (degree 1) -> Neighbor degrees: [2]
# Node Hatonosu (degree 2) -> Neighbor degrees: [2, 3]
# Node Shiromaru (degree 2) -> Neighbor degrees: [2, 2]
# Node Oku-Tama (degree 1) -> Neighbor degrees: [2]
# Node Higashi-Kashiwazaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Nakadōri (degree 2) -> Neighbor degrees: [2, 2]
# Node Arahama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kariwa (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishiyama (degree 2) -> Neighbor degrees: [2, 2]
# Node Raihai (degree 2) -> Neighbor degrees: [2, 2]
# Node Ishiji (degree 2) -> Neighbor degrees: [2, 2]
# Node Oginojō (degree 2) -> Neighbor degrees: [2, 2]
# Node Izumozaki (degree 1) -> Neighbor degrees: [1]
# Node Ojimaya (degree 1) -> Neighbor degrees: [2]
# Node Kirihara (degree 2) -> Neighbor degrees: [2, 2]
# Node Teradomari (degree 2) -> Neighbor degrees: [2, 2]
# Node Bunsui (degree 2) -> Neighbor degrees: [2, 2]
# Node Aōzu (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Yoshida (degree 2) -> Neighbor degrees: [2, 2]
# Node Kita-Yoshida (degree 2) -> Neighbor degrees: [4, 3]
# Node Iwamuro (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Sone (degree 1) -> Neighbor degrees: [1]
# Node Echigo-Akatsuka (degree 2) -> Neighbor degrees: [2, 2]
# Node Uchinonishigaoka (degree 2) -> Neighbor degrees: [2, 2]
# Node Uchino (degree 2) -> Neighbor degrees: [2, 2]
# Node Niigata University (degree 2) -> Neighbor degrees: [2, 2]
# Node Terao (degree 2) -> Neighbor degrees: [1, 2]
# Node Kobari (degree 2) -> Neighbor degrees: [2, 2]
# Node Aoyama (degree 3) -> Neighbor degrees: [2, 2, 2]
# Node Kuzumi (degree 2) -> Neighbor degrees: [2, 2]
# Node Namegawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimōsa-Kōzaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōto (degree 2) -> Neighbor degrees: [2, 3]
# Node Suigō (degree 2) -> Neighbor degrees: [2, 1]
# Node Omigawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Sasagawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Shimōsa-Tachibana (degree 2) -> Neighbor degrees: [2, 4]
# Node Shimōsa-Toyosato (degree 2) -> Neighbor degrees: [2, 2]
# Node Shiishiba (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuruta (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanuma (degree 2) -> Neighbor degrees: [2, 2]
# Node Fubasami (degree 2) -> Neighbor degrees: [2, 1]
# Node Shimotsuke-Ōsawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Imaichi (degree 2) -> Neighbor degrees: [3, 2]
# Node Nikkō (degree 1) -> Neighbor degrees: [2]
# Node Kamatori (degree 2) -> Neighbor degrees: [2, 2]
# Node Honda (degree 2) -> Neighbor degrees: [2, 2]
# Node Toke (degree 2) -> Neighbor degrees: [2, 2]
# Node Honnō (degree 1) -> Neighbor degrees: [2]
# Node Shim-Mobara (degree 2) -> Neighbor degrees: [2, 2]
# Node Mobara (degree 2) -> Neighbor degrees: [2, 2]
# Node Yatsumi (degree 2) -> Neighbor degrees: [2, 1]
# Node Kazusa-Ichinomiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Torami (degree 2) -> Neighbor degrees: [2, 3]
# Node Taitō (degree 2) -> Neighbor degrees: [2, 2]
# Node Chōjamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Mikado (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōhara (degree 2) -> Neighbor degrees: [2, 2]
# Node Namihana (degree 2) -> Neighbor degrees: [2, 2]
# Node Onjuku (degree 2) -> Neighbor degrees: [2, 2]
# Node Katsuura (degree 2) -> Neighbor degrees: [2, 2]
# Node Ubara (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazusa-Okitsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Namegawa-Island (degree 2) -> Neighbor degrees: [2, 2]
# Node Awa-Kominato (degree 2) -> Neighbor degrees: [2, 1]
# Node Awa-Amatsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Akita (degree 1) -> Neighbor degrees: [2]
# Node Izumi-Sotoasahikawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuchizaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Iijima (degree 2) -> Neighbor degrees: [2, 2]
# Node Oiwake (degree 2) -> Neighbor degrees: [2, 2]
# Node Detohama (degree 2) -> Neighbor degrees: [2, 2]
# Node Kami-Futada (degree 2) -> Neighbor degrees: [2, 2]
# Node Futada (degree 2) -> Neighbor degrees: [2, 2]
# Node Tennō (degree 2) -> Neighbor degrees: [2, 2]
# Node Funakoshi (degree 2) -> Neighbor degrees: [2, 2]
# Node Wakimoto (degree 2) -> Neighbor degrees: [2, 2]
# Node Hadachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Oga (degree 1) -> Neighbor degrees: [2]
# Node Yonezawa (degree 1) -> Neighbor degrees: [2]
# Node Minami-Yonezawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Nishi-Yonezawa (degree 1) -> Neighbor degrees: [2]
# Node Chūgun (degree 1) -> Neighbor degrees: [2]
# Node Uzen-Komatsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Inukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Imaizumi (degree 2) -> Neighbor degrees: [2, 2]
# Node Hagyū (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Tsubaki (degree 2) -> Neighbor degrees: [1, 2]
# Node Tenoko (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzen-Numazawa (degree 2) -> Neighbor degrees: [1, 2]
# Node Isaryō (degree 2) -> Neighbor degrees: [2, 2]
# Node Uzem-Matsuoka (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Kanamaru (degree 1) -> Neighbor degrees: [2]
# Node Echigo-Katakai (degree 2) -> Neighbor degrees: [2, 2]
# Node Echigo-Shimoseki (degree 2) -> Neighbor degrees: [2, 1]
# Node Echigo-Ōshima (degree 2) -> Neighbor degrees: [2, 2]
# Node Hachiōji (degree 1) -> Neighbor degrees: [2]
# Node Kita-Hachiōji (degree 2) -> Neighbor degrees: [2, 2]
# Node Komiya (degree 2) -> Neighbor degrees: [2, 2]
# Node Haijima (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Fussa (degree 2) -> Neighbor degrees: [2, 2]
# Node Hakonegasaki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kaneko (degree 2) -> Neighbor degrees: [1, 2]
# Node Higashi-Hannō (degree 2) -> Neighbor degrees: [2, 2]
# Node Komagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Moro (degree 2) -> Neighbor degrees: [1, 2]
# Node Ogose (degree 2) -> Neighbor degrees: [2, 2]
# Node Myōkaku (degree 2) -> Neighbor degrees: [2, 4]
# Node Ogawamachi (degree 2) -> Neighbor degrees: [2, 1]
# Node Takezawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Orihara (degree 2) -> Neighbor degrees: [2, 2]
# Node Yorii (degree 1) -> Neighbor degrees: [1]
# Node Matsuhisa (degree 1) -> Neighbor degrees: [2]
# Node Kodama (degree 2) -> Neighbor degrees: [2, 2]
# Node Tanshō (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumma-Fujioka (degree 2) -> Neighbor degrees: [2, 3]
# Node Kita-Fujioka (degree 2) -> Neighbor degrees: [2, 2]
# Node Kuriyagawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Sugō (degree 2) -> Neighbor degrees: [2, 2]
# Node Takizawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Sibutami (degree 2) -> Neighbor degrees: [2, 2]
# Node Kōma (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Ōbuke (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōbuke (degree 2) -> Neighbor degrees: [2, 2]
# Node Tairadate (degree 2) -> Neighbor degrees: [2, 2]
# Node Kitamori (degree 2) -> Neighbor degrees: [2, 2]
# Node Matsuohachimantai (degree 2) -> Neighbor degrees: [1, 2]
# Node Appi-Kōgen (degree 2) -> Neighbor degrees: [2, 2]
# Node Akasakata (degree 2) -> Neighbor degrees: [2, 2]
# Node Koyanohata (degree 2) -> Neighbor degrees: [2, 3]
# Node Arayashimmachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yokoma (degree 2) -> Neighbor degrees: [2, 2]
# Node Tayama (degree 2) -> Neighbor degrees: [2, 2]
# Node Anihata (degree 2) -> Neighbor degrees: [2, 2]
# Node Yuze-Onsen (degree 2) -> Neighbor degrees: [2, 1]
# Node Hachimantai (degree 2) -> Neighbor degrees: [2, 1]
# Node Rikucyū-Ōsato (degree 2) -> Neighbor degrees: [2, 2]
# Node Kazunohanawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibahira (degree 2) -> Neighbor degrees: [2, 1]
# Node Towadaminami (degree 2) -> Neighbor degrees: [2, 2]
# Node Suehiro (degree 2) -> Neighbor degrees: [2, 2]
# Node Dobukai (degree 2) -> Neighbor degrees: [2, 2]
# Node Sawajiri (degree 2) -> Neighbor degrees: [2, 2]
# Node Jūnisho (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōtaki-Onsen (degree 2) -> Neighbor degrees: [2, 1]
# Node Ōgita (degree 2) -> Neighbor degrees: [3, 2]
# Node Higashi-Ōdate (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōdate (degree 1) -> Neighbor degrees: [2]
# Node Gumma-Sōja (degree 2) -> Neighbor degrees: [2, 2]
# Node Yagihara (degree 2) -> Neighbor degrees: [2, 2]
# Node Shibukawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Kanashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Ubashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Onogami (degree 2) -> Neighbor degrees: [2, 2]
# Node Onogami-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Ichishiro (degree 2) -> Neighbor degrees: [1, 2]
# Node Nakanojō (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumma-Haramachi (degree 2) -> Neighbor degrees: [2, 3]
# Node Gōbara (degree 2) -> Neighbor degrees: [2, 2]
# Node Yagura (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawarayu-Onsen (degree 2) -> Neighbor degrees: [2, 2]
# Node Naganoharakusatsuguchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Gumma-Ōtsu (degree 2) -> Neighbor degrees: [2, 2]
# Node Haneo (degree 2) -> Neighbor degrees: [2, 2]
# Node Fukurogura (degree 2) -> Neighbor degrees: [2, 1]
# Node Manza･kazawaguchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Ōmae (degree 1) -> Neighbor degrees: [2]
# Node Sendai Airport (degree 1) -> Neighbor degrees: [2]
# Node Mitazono (degree 2) -> Neighbor degrees: [2, 2]
# Node Morisekinoshita (degree 2) -> Neighbor degrees: [2, 2]
# Node Natori (degree 2) -> Neighbor degrees: [2, 2]
# Node Minami-Sendai (degree 2) -> Neighbor degrees: [2, 2]
# Node Taishidō (degree 2) -> Neighbor degrees: [2, 2]
# Node Nagamachi (degree 2) -> Neighbor degrees: [2, 2]
# Node Masukata (degree 2) -> Neighbor degrees: [1, 3]
# Node Uzen-Zennami (degree 2) -> Neighbor degrees: [2, 2]
# Node Tsuya (degree 2) -> Neighbor degrees: [2, 2]
# Node Furukuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Takaya (degree 2) -> Neighbor degrees: [1, 2]
# Node Kiyokawa (degree 2) -> Neighbor degrees: [2, 2]
# Node Karikawa (degree 2) -> Neighbor degrees: [3, 2]
# Node Minamino (degree 2) -> Neighbor degrees: [2, 2]
# Node Wabuchi (degree 2) -> Neighbor degrees: [2, 2]
# Node Nonodake (degree 2) -> Neighbor degrees: [1, 2]
# Node Rikuzen-Toyosato (degree 2) -> Neighbor degrees: [2, 2]
# Node Mitakedō (degree 2) -> Neighbor degrees: [2, 2]
# Node Yanaizu (degree 1) -> Neighbor degrees: [2]
# Node Otabayashi (degree 2) -> Neighbor degrees: [2, 2]
# Node Yūki (degree 2) -> Neighbor degrees: [2, 2]
# Node Higashi-Yūki (degree 2) -> Neighbor degrees: [2, 2]
# Node Kawashima (degree 2) -> Neighbor degrees: [2, 2]
# Node Tamado (degree 2) -> Neighbor degrees: [2, 2]
# Node Shimodate (degree 2) -> Neighbor degrees: [2, 3]
# Node Niihari (degree 2) -> Neighbor degrees: [2, 2]
# Node Yamato (degree 2) -> Neighbor degrees: [2, 2]
# Node Iwase (degree 2) -> Neighbor degrees: [2, 2]
# Node Haguro (degree 2) -> Neighbor degrees: [2, 3]
# Node Fukuhara (degree 2) -> Neighbor degrees: [2, 2]
# Node Inada (degree 2) -> Neighbor degrees: [2, 2]
# Node Kasama (degree 2) -> Neighbor degrees: [2, 2]
# Node Shishido (degree 2) -> Neighbor degrees: [2, 2]
# Node Tomobe (degree 1) -> Neighbor degrees: [2]
# Degree sum: {2: 2634, 3: 87, 1: 193, 0: 0, 4: 16}
# Degree count: {2: 1336, 3: 42, 1: 100, 0: 0, 4: 8}
# k_nn(k): {2: 1.971556886227545, 3: 2.0714285714285716, 1: 1.93, 0: 0, 4: 2.0}

# %%
# pearson correlation coefficient for the randomized graph
results_randomized = calculate_degree_correlation(randomized_undir_G)
print(f"Pearson Degree Correlation Coefficient (Randomized): {results_randomized['pearson_coefficient']}")
# Out:
# Pearson Degree Correlation Coefficient (Randomized): 0.05099688473520254
